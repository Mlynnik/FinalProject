# %% [markdown]
# # Классификация марок автомобилей: улучшенный пайплайн обучения и анализа
#
# В этой версии ноутбука добавлены:
#
# - устойчивый запуск на CPU/GPU без падения при отсутствии видеокарты;
# - проверка структуры датасета, битых изображений и пересечений между `train`, `val`, `test`;
# - анализ дисбаланса классов и расчёт `class_weight`;
# - более сильная аугментация;
# - метрики `accuracy`, `top-3 accuracy`, `top-5 accuracy`;
# - улучшенный classifier head для transfer learning;
# - поэтапный fine-tuning EfficientNetB0;
# - confusion matrix, classification report и анализ ошибочных предсказаний;
# - заготовки для экспериментов с другими backbone-моделями и большим разрешением.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf

print("Версия TensorFlow:", tf.__version__)
print("Доступные GPU:", tf.config.list_physical_devices('GPU'))
tf.config.set_visible_devices(tf.config.list_physical_devices('GPU')[0], 'GPU')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777468717.222594  317334 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Версия TensorFlow: 2.21.0
# Доступные GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import random
from pathlib import Path
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score

# %%
# Воспроизводимость экспериментов.
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = (256, 256)
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE

DATA_DIR = Path("/home/sm/Desktop/ml/CarBrandClassificationDataset")

# %% [markdown]
# ## 1. Загрузка структуры датасета
#
# Ожидается структура:
#
# ```text
# CarBrandClassificationDataset/
# ├── train/
# │   ├── class_1/
# │   └── ...
# ├── val/
# │   ├── class_1/
# │   └── ...
# └── test/
#     ├── class_1/
#     └── ...
# ```
#
# В таблицы ниже собираются пути к изображениям и строковые метки классов.

# %%
train_base = DATA_DIR / "train"
val_base = DATA_DIR / "val"
test_base = DATA_DIR / "test"

IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

def build_split_df(split_dir: Path) -> pd.DataFrame:
    """Собирает таблицу path/label для одного split'а."""
    if not split_dir.exists():
        raise FileNotFoundError(f"Папка split'а не найдена: {split_dir}")

    rows = []
    class_dirs = sorted([d for d in split_dir.iterdir() if d.is_dir()])
    for cls_dir in class_dirs:
        cls = cls_dir.name
        for f in cls_dir.rglob("*"):
            if f.is_file() and f.suffix.lower() in IMAGE_EXTENSIONS:
                rows.append((str(f), cls))
    return pd.DataFrame(rows, columns=["path", "label"])

df_train = build_split_df(train_base)
df_val = build_split_df(val_base)
df_test = build_split_df(test_base)

print("Количество изображений:")
print("Train:", len(df_train), "| классов:", df_train["label"].nunique())
print("Val  :", len(df_val), "| классов:", df_val["label"].nunique())
print("Test :", len(df_test), "| классов:", df_test["label"].nunique())

display(pd.concat({
    "train": df_train["label"].value_counts().sort_index(),
    "val": df_val["label"].value_counts().sort_index(),
    "test": df_test["label"].value_counts().sort_index(),
}, axis=1).fillna(0).astype(int).head())
# Out:
# Количество изображений:
# Train: 11517 | классов: 33
# Val  : 2475 | классов: 33
# Test : 2475 | классов: 33
#               train  val  test
# label
# Acura           349   75    75
# Aston Martin    349   75    75
# Audi            349   75    75
# BMW             349   75    75
# Bentley         349   75    75

# %%
# Единое отображение классов в индексы.
classes = sorted(df_train["label"].unique().tolist())
class2idx = {c: i for i, c in enumerate(classes)}
idx2class = {i: c for c, i in class2idx.items()}
num_classes = len(classes)

for name, df in [("val", df_val), ("test", df_test)]:
    missing = set(df["label"].unique()) - set(classes)
    if missing:
        raise ValueError(f"В {name} есть классы, которых нет в train: {sorted(missing)}")

df_train["label_idx"] = df_train["label"].map(class2idx)
df_val["label_idx"] = df_val["label"].map(class2idx)
df_test["label_idx"] = df_test["label"].map(class2idx)

print("Число классов:", num_classes)
print("Пример отображения:", list(class2idx.items())[:10])
df_train.head()
# Out:
# Число классов: 33
# Пример отображения: [('Acura', 0), ('Aston Martin', 1), ('Audi', 2), ('BMW', 3), ('Bentley', 4), ('Buick', 5), ('Cadillac', 6), ('Chevrolet', 7), ('Chrysler', 8), ('Dodge', 9)]
#                                                 path  label  label_idx
# 0  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 1  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 2  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 3  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 4  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0

# %% [markdown]
# ## 2. Проверка качества данных
#
# Перед улучшением модели важно проверить сам датасет:
#
# - нет ли сильного дисбаланса классов;
# - нет ли пересечений одних и тех же файлов между `train`, `val`, `test`;
# - читаются ли изображения без ошибок;
# - совпадает ли набор классов между split'ами.
#
# Такая проверка часто даёт больший прирост качества, чем замена архитектуры.

# %%
def plot_class_distribution(df: pd.DataFrame, title: str) -> None:
    counts = df["label"].value_counts().sort_values(ascending=False)
    plt.figure(figsize=(14, 5))
    sns.barplot(x=counts.index, y=counts.values)
    plt.title(title)
    plt.xlabel("Класс")
    plt.ylabel("Количество изображений")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

plot_class_distribution(df_train, "Распределение классов в train")
plot_class_distribution(df_val, "Распределение классов в val")
plot_class_distribution(df_test, "Распределение классов в test")

class_counts = df_train["label_idx"].value_counts().sort_index()
imbalance_ratio = class_counts.max() / max(class_counts.min(), 1)
print(f"Коэффициент дисбаланса train max/min: {imbalance_ratio:.2f}")

# class_weight помогает, если часть классов встречается заметно реже.
class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(num_classes),
    y=df_train["label_idx"].values
)
class_weight = {i: float(w) for i, w in enumerate(class_weights_array)}
print("Пример class_weight:", dict(list(class_weight.items())[:10]))
# Out:
# Коэффициент дисбаланса train max/min: 1.00
# Пример class_weight: {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 1.0, 8: 1.0, 9: 1.0}

# %% [markdown]
# ## 3. `tf.data`-пайплайн и аугментация
#
# Для baseline-модели используются изображения в диапазоне `[0, 1]`.
#
# Для EfficientNet используется `preprocess_input`, совместимый с ImageNet-предобучением. Аугментация стала сильнее, но без чрезмерных искажений: марку машины нельзя менять агрессивными трансформациями.

# %%
def decode_image(path):
    """Читает изображение, приводит к RGB, float32 и нужному размеру."""
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize_with_pad(img, IMG_SIZE[0], IMG_SIZE[1])
    return img

augmenter = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.08, 0.08),
    layers.RandomContrast(0.15),
], name="augmenter")

def make_ds(paths, labels=None, augment=False, shuffle=False, efficientnet_preprocess=False):
    """Создаёт tf.data.Dataset для обучения или инференса."""
    p = tf.constant(paths)

    if labels is None:
        ds = tf.data.Dataset.from_tensor_slices(p)
        ds = ds.map(lambda x: decode_image(x), num_parallel_calls=AUTO)
    else:
        l = tf.constant(labels, dtype=tf.int32)
        ds = tf.data.Dataset.from_tensor_slices((p, l))
        ds = ds.map(lambda x, y: (decode_image(x), y), num_parallel_calls=AUTO)

    if shuffle:
        ds = ds.shuffle(buffer_size=min(len(paths), 4096), seed=SEED, reshuffle_each_iteration=True)

    if augment and labels is not None:
        ds = ds.map(lambda x, y: (augmenter(x, training=True), y), num_parallel_calls=AUTO)

    if efficientnet_preprocess:
        if labels is None:
            ds = ds.map(lambda x: preprocess_input(x * 255.0), num_parallel_calls=AUTO)
        else:
            ds = ds.map(lambda x, y: (preprocess_input(x * 255.0), y), num_parallel_calls=AUTO)

    ds = ds.batch(BATCH_SIZE).prefetch(AUTO)
    return ds

train_ds = make_ds(
    df_train["path"].tolist(),
    df_train["label_idx"].tolist(),
    augment=True,
    shuffle=True,
    efficientnet_preprocess=False,
)
val_ds = make_ds(df_val["path"].tolist(), df_val["label_idx"].tolist())
test_ds = make_ds(df_test["path"].tolist(), df_test["label_idx"].tolist())

train_ds_tl = make_ds(
    df_train["path"].tolist(),
    df_train["label_idx"].tolist(),
    augment=True,
    shuffle=True,
    efficientnet_preprocess=True,
)
val_ds_tl = make_ds(
    df_val["path"].tolist(),
    df_val["label_idx"].tolist(),
    efficientnet_preprocess=True,
)
test_ds_tl = make_ds(
    df_test["path"].tolist(),
    df_test["label_idx"].tolist(),
    efficientnet_preprocess=True,
)

for bx, by in train_ds_tl.take(1):
    print("Batch:", bx.shape, bx.dtype, "| labels:", by.shape)
# Out:
# Batch: (32, 256, 256, 3) <dtype: 'float32'> | labels: (32,)

# %% [markdown]
# ## 4. Baseline CNN
#
# Baseline нужен не для максимального качества, а как контрольная точка. Если baseline даёт результат около случайного угадывания, это подтверждает необходимость transfer learning.

# %%
os.makedirs("models", exist_ok=True)

def build_baseline_model(num_classes: int) -> tf.keras.Model:
    inputs = layers.Input(shape=(*IMG_SIZE, 3))

    x = layers.Conv2D(32, 3, padding="same", activation="relu")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(64, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(128, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.35)(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.30)(x)

    logits = layers.Dense(num_classes)(x)
    outputs = layers.Activation("softmax", dtype="float32")(logits)

    model = models.Model(inputs, outputs, name="baseline_cnn")
    model.compile(
        optimizer=optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top3_accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_accuracy"),
        ],
    )
    return model

baseline = build_baseline_model(num_classes)
baseline.summary()
# Out:
# Model: "baseline_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 33)             │         8,481 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 33)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 135,649 (529.88 KB)
#  Trainable params: 135,201 (528.13 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
baseline_callbacks = [
    callbacks.ModelCheckpoint(
        "models/baseline_best.keras",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=1,
    ),
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=5,
        restore_best_weights=True,
        verbose=1,
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        verbose=1,
    ),
]

history_baseline = baseline.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=baseline_callbacks,
    class_weight=class_weight,
)
# Out:
# Epoch 1/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.0619 - loss: 3.3291 - top3_accuracy: 0.1748 - top5_accuracy: 0.2794
# Epoch 1: val_accuracy improved from None to 0.04121, saving model to models/baseline_best.keras
#
# Epoch 1: finished saving model to models/baseline_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 123s 303ms/step - accuracy: 0.0574 - loss: 3.4116 - top3_accuracy: 0.1596 - top5_accuracy: 0.2519 - val_accuracy: 0.0412 - val_loss: 3.6390 - val_top3_accuracy: 0.1014 - val_top5_accuracy: 0.1624 - learning_rate: 0.0010
# Epoch 2/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.0504 - loss: 3.3975 - top3_accuracy: 0.1403 - top5_accuracy: 0.2236
# Epoch 2: val_accuracy did not improve from 0.04121
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 37s 102ms/step - accuracy: 0.0658 - loss: 3.3662 - top3_accuracy: 0.1763 - top5_accuracy: 0.2730 - val_accuracy: 0.0356 - val_loss: 3.7111 - val_top3_accuracy: 0.1079 - val_top5_accuracy: 0.1745 - learning_rate: 0.0010
# Epoch 3/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.0547 - loss: 3.3968 - top3_accuracy: 0.1470 - top5_accuracy: 0.2246
# Epoch 3: val_accuracy improved from 0.04121 to 0.04364, saving model to models/baseline_best.keras
#
# Epoch 3: finished saving model to models/baseline_best.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 103ms/step - accuracy: 0.0725 - loss: 3.3397 - top3_accuracy: 0.1915 - top5_accuracy: 0.2891 - val_accuracy: 0.0436 - val_loss: 3.9005 - val_top3_accuracy: 0.1111 - val_top5_accuracy: 0.1758 - learning_rate: 0.0010
# Epoch 4/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.0473 - loss: 3.4720 - top3_accuracy: 0.1253 - top5_accuracy: 0.1949
# Epoch 4: val_accuracy did not improve from 0.04364
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 104ms/step - accuracy: 0.0688 - loss: 3.3747 - top3_accuracy: 0.1798 - top5_accuracy: 0.2721 - val_accuracy: 0.0416 - val_loss: 3.7403 - val_top3_accuracy: 0.1180 - val_top5_accuracy: 0.1871 - learning_rate: 5.0000e-04
# Epoch 5/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.0595 - loss: 3.3865 - top3_accuracy: 0.1507 - top5_accuracy: 0.2276
# Epoch 5: val_accuracy did not improve from 0.04364
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 104ms/step - accuracy: 0.0778 - loss: 3.3353 - top3_accuracy: 0.1975 - top5_accuracy: 0.2922 - val_accuracy: 0.0408 - val_loss: 3.5674 - val_top3_accuracy: 0.1212 - val_top5_accuracy: 0.1814 - learning_rate: 5.0000e-04
# Epoch 6/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.0692 - loss: 3.3256 - top3_accuracy: 0.1682 - top5_accuracy: 0.2567
# Epoch 6: val_accuracy improved from 0.04364 to 0.05495, saving model to models/baseline_best.keras
#
# Epoch 6: finished saving model to models/baseline_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 105ms/step - accuracy: 0.0805 - loss: 3.3014 - top3_accuracy: 0.2053 - top5_accuracy: 0.3023 - val_accuracy: 0.0549 - val_loss: 3.6887 - val_top3_accuracy: 0.1273 - val_top5_accuracy: 0.1964 - learning_rate: 5.0000e-04
# Epoch 7/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.0666 - loss: 3.3337 - top3_accuracy: 0.1667 - top5_accuracy: 0.2597
# Epoch 7: val_accuracy did not improve from 0.05495
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 39s 106ms/step - accuracy: 0.0798 - loss: 3.2997 - top3_accuracy: 0.2020 - top5_accuracy: 0.3098 - val_accuracy: 0.0509 - val_loss: 3.5424 - val_top3_accuracy: 0.1212 - val_top5_accuracy: 0.1952 - learning_rate: 5.0000e-04
# Epoch 8/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.0685 - loss: 3.3256 - top3_accuracy: 0.1674 - top5_accuracy: 0.2630
# Epoch 8: val_accuracy did not improve from 0.05495
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 104ms/step - accuracy: 0.0834 - loss: 3.2821 - top3_accuracy: 0.2077 - top5_accuracy: 0.3177 - val_accuracy: 0.0461 - val_loss: 3.5458 - val_top3_accuracy: 0.1325 - val_top5_accuracy: 0.1968 - learning_rate: 5.0000e-04
# Epoch 9/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.0646 - loss: 3.2967 - top3_accuracy: 0.1779 - top5_accuracy: 0.2735
# Epoch 9: val_accuracy did not improve from 0.05495
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 104ms/step - accuracy: 0.0797 - loss: 3.2791 - top3_accuracy: 0.2104 - top5_accuracy: 0.3175 - val_accuracy: 0.0477 - val_loss: 3.5316 - val_top3_accuracy: 0.1127 - val_top5_accuracy: 0.1895 - learning_rate: 5.0000e-04
# Epoch 10/10
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.0617 - loss: 3.3514 - top3_accuracy: 0.1647 - top5_accuracy: 0.2519
# Epoch 10: val_accuracy improved from 0.05495 to 0.06505, saving model to models/baseline_best.keras
#
# Epoch 10: finished saving model to models/baseline_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 38s 104ms/step - accuracy: 0.0831 - loss: 3.2894 - top3_accuracy: 0.2128 - top5_accuracy: 0.3148 - val_accuracy: 0.0651 - val_loss: 3.4948 - val_top3_accuracy: 0.1547 - val_top5_accuracy: 0.2218 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# ## 5. Transfer learning: EfficientNetB0
#
# По сравнению с исходным вариантом улучшены:
#
# - classifier head: `Dense + BatchNorm + Dropout`;
# - метрики top-3/top-5;
# - `class_weight` для борьбы с дисбалансом;
# - более аккуратный fine-tuning с меньшим learning rate;
# - возможность размораживать backbone блоками.
#
# Для дальнейших экспериментов можно заменить `EfficientNetB0` на `EfficientNetB2/B3`, `MobileNetV3Large`, `ResNet50V2`, `ConvNeXtTiny`.

# %%
def build_efficientnet_b2(num_classes: int, img_size=IMG_SIZE, dropout=0.40) -> tuple[tf.keras.Model, tf.keras.Model]:
    """Создаёт модель EfficientNetB0 + улучшенную классификационную голову."""
    base = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(*img_size, 3),
    )
    base.trainable = False

    inputs = layers.Input(shape=(*img_size, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Dense(256, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout * 0.75)(x)

    logits = layers.Dense(num_classes)(x)
    outputs = layers.Activation("softmax", dtype="float32")(logits)

    model = models.Model(inputs, outputs, name="efficientnetb0_car_brand")
    return model, base

def compile_model(model: tf.keras.Model, lr: float) -> None:
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="sparse_categorical_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top3_accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_accuracy"),
        ],
    )

model_tl, base = build_efficientnet_b2(num_classes)
compile_model(model_tl, lr=3e-4)
model_tl.summary()
# Out:
# Model: "efficientnetb0_car_brand"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 8, 8, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 33)             │         8,481 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 33)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,848,324 (18.49 MB)
#  Trainable params: 797,217 (3.04 MB)
#  Non-trainable params: 4,051,107 (15.45 MB)

# %%
tl_callbacks = [
    callbacks.ModelCheckpoint(
        "models/effb0_best.keras",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=1,
    ),
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=6,
        restore_best_weights=True,
        verbose=1,
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-7,
        verbose=1,
    ),
    callbacks.CSVLogger("models/effb0_training_log.csv", append=False),
]

print("Этап 1: обучение classifier head при замороженном backbone.")
hist_warmup = model_tl.fit(
    train_ds_tl,
    validation_data=val_ds_tl,
    epochs=12,
    callbacks=tl_callbacks,
    class_weight=class_weight,
)
# Out:
# Этап 1: обучение classifier head при замороженном backbone.
# Epoch 1/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.0710 - loss: 4.0857 - top3_accuracy: 0.1716 - top5_accuracy: 0.2545
# Epoch 1: val_accuracy improved from None to 0.14182, saving model to models/effb0_best.keras
#
# Epoch 1: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 81s 161ms/step - accuracy: 0.0834 - loss: 3.8942 - top3_accuracy: 0.1966 - top5_accuracy: 0.2833 - val_accuracy: 0.1418 - val_loss: 3.1591 - val_top3_accuracy: 0.3042 - val_top5_accuracy: 0.4202 - learning_rate: 3.0000e-04
# Epoch 2/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1227 - loss: 3.4479 - top3_accuracy: 0.2702 - top5_accuracy: 0.3718
# Epoch 2: val_accuracy improved from 0.14182 to 0.17657, saving model to models/effb0_best.keras
#
# Epoch 2: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.1294 - loss: 3.4080 - top3_accuracy: 0.2756 - top5_accuracy: 0.3783 - val_accuracy: 0.1766 - val_loss: 3.0158 - val_top3_accuracy: 0.3588 - val_top5_accuracy: 0.4659 - learning_rate: 3.0000e-04
# Epoch 3/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1554 - loss: 3.2145 - top3_accuracy: 0.3211 - top5_accuracy: 0.4354
# Epoch 3: val_accuracy improved from 0.17657 to 0.21051, saving model to models/effb0_best.keras
#
# Epoch 3: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.1656 - loss: 3.1754 - top3_accuracy: 0.3270 - top5_accuracy: 0.4390 - val_accuracy: 0.2105 - val_loss: 2.8645 - val_top3_accuracy: 0.3992 - val_top5_accuracy: 0.5240 - learning_rate: 3.0000e-04
# Epoch 4/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1849 - loss: 3.0369 - top3_accuracy: 0.3682 - top5_accuracy: 0.4789
# Epoch 4: val_accuracy improved from 0.21051 to 0.22747, saving model to models/effb0_best.keras
#
# Epoch 4: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.1929 - loss: 3.0073 - top3_accuracy: 0.3723 - top5_accuracy: 0.4845 - val_accuracy: 0.2275 - val_loss: 2.7825 - val_top3_accuracy: 0.4287 - val_top5_accuracy: 0.5539 - learning_rate: 3.0000e-04
# Epoch 5/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1953 - loss: 2.9499 - top3_accuracy: 0.3833 - top5_accuracy: 0.5048
# Epoch 5: val_accuracy improved from 0.22747 to 0.23354, saving model to models/effb0_best.keras
#
# Epoch 5: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 30s 80ms/step - accuracy: 0.2113 - loss: 2.9076 - top3_accuracy: 0.3962 - top5_accuracy: 0.5130 - val_accuracy: 0.2335 - val_loss: 2.7418 - val_top3_accuracy: 0.4461 - val_top5_accuracy: 0.5693 - learning_rate: 3.0000e-04
# Epoch 6/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2240 - loss: 2.8537 - top3_accuracy: 0.4109 - top5_accuracy: 0.5310
# Epoch 6: val_accuracy improved from 0.23354 to 0.25980, saving model to models/effb0_best.keras
#
# Epoch 6: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 30s 80ms/step - accuracy: 0.2371 - loss: 2.8087 - top3_accuracy: 0.4209 - top5_accuracy: 0.5385 - val_accuracy: 0.2598 - val_loss: 2.6545 - val_top3_accuracy: 0.4776 - val_top5_accuracy: 0.6053 - learning_rate: 3.0000e-04
# Epoch 7/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2443 - loss: 2.7677 - top3_accuracy: 0.4396 - top5_accuracy: 0.5566
# Epoch 7: val_accuracy improved from 0.25980 to 0.26182, saving model to models/effb0_best.keras
#
# Epoch 7: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 30s 81ms/step - accuracy: 0.2533 - loss: 2.7325 - top3_accuracy: 0.4493 - top5_accuracy: 0.5666 - val_accuracy: 0.2618 - val_loss: 2.6798 - val_top3_accuracy: 0.4687 - val_top5_accuracy: 0.5790 - learning_rate: 3.0000e-04
# Epoch 8/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2539 - loss: 2.6844 - top3_accuracy: 0.4631 - top5_accuracy: 0.5807
# Epoch 8: val_accuracy improved from 0.26182 to 0.28848, saving model to models/effb0_best.keras
#
# Epoch 8: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 30s 80ms/step - accuracy: 0.2653 - loss: 2.6505 - top3_accuracy: 0.4702 - top5_accuracy: 0.5870 - val_accuracy: 0.2885 - val_loss: 2.5683 - val_top3_accuracy: 0.4889 - val_top5_accuracy: 0.6162 - learning_rate: 3.0000e-04
# Epoch 9/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2650 - loss: 2.6321 - top3_accuracy: 0.4708 - top5_accuracy: 0.5994
# Epoch 9: val_accuracy did not improve from 0.28848
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.2835 - loss: 2.5835 - top3_accuracy: 0.4868 - top5_accuracy: 0.6084 - val_accuracy: 0.2735 - val_loss: 2.5897 - val_top3_accuracy: 0.4966 - val_top5_accuracy: 0.6085 - learning_rate: 3.0000e-04
# Epoch 10/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2768 - loss: 2.6117 - top3_accuracy: 0.4879 - top5_accuracy: 0.6021
# Epoch 10: val_accuracy improved from 0.28848 to 0.29939, saving model to models/effb0_best.keras
#
# Epoch 10: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.2923 - loss: 2.5508 - top3_accuracy: 0.4998 - top5_accuracy: 0.6147 - val_accuracy: 0.2994 - val_loss: 2.5136 - val_top3_accuracy: 0.5034 - val_top5_accuracy: 0.6255 - learning_rate: 3.0000e-04
# Epoch 11/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2936 - loss: 2.5311 - top3_accuracy: 0.5053 - top5_accuracy: 0.6148
# Epoch 11: val_accuracy improved from 0.29939 to 0.31838, saving model to models/effb0_best.keras
#
# Epoch 11: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.3051 - loss: 2.4950 - top3_accuracy: 0.5160 - top5_accuracy: 0.6286 - val_accuracy: 0.3184 - val_loss: 2.4587 - val_top3_accuracy: 0.5341 - val_top5_accuracy: 0.6428 - learning_rate: 3.0000e-04
# Epoch 12/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3003 - loss: 2.4913 - top3_accuracy: 0.5172 - top5_accuracy: 0.6335
# Epoch 12: val_accuracy improved from 0.31838 to 0.31960, saving model to models/effb0_best.keras
#
# Epoch 12: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.3194 - loss: 2.4374 - top3_accuracy: 0.5302 - top5_accuracy: 0.6508 - val_accuracy: 0.3196 - val_loss: 2.4517 - val_top3_accuracy: 0.5269 - val_top5_accuracy: 0.6453 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# ## 6. Fine-tuning EfficientNetB0
#
# После warmup размораживаем только верхнюю часть backbone. BatchNorm-слои оставляем замороженными: это обычно делает fine-tuning стабильнее на небольших датасетах.
#
# Если качество растёт медленно, можно попробовать:
#
# - `FINE_TUNE_LAYERS = 80` или `120`;
# - learning rate `1e-5` или `3e-6`;
# - большее разрешение `IMG_SIZE = (260, 260)`.

# %%
def set_fine_tuning(base_model: tf.keras.Model, fine_tune_layers: int) -> None:
    """Размораживает последние fine_tune_layers слоёв, кроме BatchNormalization."""
    base_model.trainable = True

    for layer in base_model.layers[:-fine_tune_layers]:
        layer.trainable = False

    for layer in base_model.layers:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

FINE_TUNE_LAYERS = 80
set_fine_tuning(base, fine_tune_layers=FINE_TUNE_LAYERS)

trainable_count = sum(int(layer.trainable) for layer in base.layers)
print(f"Trainable слоёв backbone: {trainable_count} из {len(base.layers)}")

compile_model(model_tl, lr=1e-5)

print("Этап 2: fine-tuning верхних слоёв EfficientNetB0.")
hist_ft = model_tl.fit(
    train_ds_tl,
    validation_data=val_ds_tl,
    epochs=35,
    callbacks=tl_callbacks,
    class_weight=class_weight,
)
# Out:
# Trainable слоёв backbone: 63 из 238
# Этап 2: fine-tuning верхних слоёв EfficientNetB0.
# Epoch 1/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.2837 - loss: 2.5084 - top3_accuracy: 0.5097 - top5_accuracy: 0.6428
# Epoch 1: val_accuracy improved from 0.31960 to 0.36242, saving model to models/effb0_best.keras
#
# Epoch 1: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 67s 134ms/step - accuracy: 0.3312 - loss: 2.3658 - top3_accuracy: 0.5512 - top5_accuracy: 0.6714 - val_accuracy: 0.3624 - val_loss: 2.3439 - val_top3_accuracy: 0.5608 - val_top5_accuracy: 0.6711 - learning_rate: 1.0000e-05
# Epoch 2/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3162 - loss: 2.3865 - top3_accuracy: 0.5451 - top5_accuracy: 0.6670
# Epoch 2: val_accuracy improved from 0.36242 to 0.37212, saving model to models/effb0_best.keras
#
# Epoch 2: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 87ms/step - accuracy: 0.3503 - loss: 2.2850 - top3_accuracy: 0.5737 - top5_accuracy: 0.6891 - val_accuracy: 0.3721 - val_loss: 2.3000 - val_top3_accuracy: 0.5677 - val_top5_accuracy: 0.6764 - learning_rate: 1.0000e-05
# Epoch 3/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3378 - loss: 2.3029 - top3_accuracy: 0.5670 - top5_accuracy: 0.6851
# Epoch 3: val_accuracy improved from 0.37212 to 0.38020, saving model to models/effb0_best.keras
#
# Epoch 3: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.3695 - loss: 2.2122 - top3_accuracy: 0.5947 - top5_accuracy: 0.7070 - val_accuracy: 0.3802 - val_loss: 2.2575 - val_top3_accuracy: 0.5774 - val_top5_accuracy: 0.6857 - learning_rate: 1.0000e-05
# Epoch 4/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3609 - loss: 2.2581 - top3_accuracy: 0.5842 - top5_accuracy: 0.6952
# Epoch 4: val_accuracy improved from 0.38020 to 0.39313, saving model to models/effb0_best.keras
#
# Epoch 4: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.3861 - loss: 2.1752 - top3_accuracy: 0.6047 - top5_accuracy: 0.7149 - val_accuracy: 0.3931 - val_loss: 2.2182 - val_top3_accuracy: 0.5972 - val_top5_accuracy: 0.6949 - learning_rate: 1.0000e-05
# Epoch 5/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3607 - loss: 2.2266 - top3_accuracy: 0.5898 - top5_accuracy: 0.7064
# Epoch 5: val_accuracy improved from 0.39313 to 0.40768, saving model to models/effb0_best.keras
#
# Epoch 5: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 34s 91ms/step - accuracy: 0.3872 - loss: 2.1566 - top3_accuracy: 0.6109 - top5_accuracy: 0.7255 - val_accuracy: 0.4077 - val_loss: 2.1856 - val_top3_accuracy: 0.6048 - val_top5_accuracy: 0.7059 - learning_rate: 1.0000e-05
# Epoch 6/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3785 - loss: 2.1890 - top3_accuracy: 0.5971 - top5_accuracy: 0.7072
# Epoch 6: val_accuracy did not improve from 0.40768
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 88ms/step - accuracy: 0.3967 - loss: 2.1278 - top3_accuracy: 0.6197 - top5_accuracy: 0.7275 - val_accuracy: 0.4073 - val_loss: 2.1682 - val_top3_accuracy: 0.6089 - val_top5_accuracy: 0.7103 - learning_rate: 1.0000e-05
# Epoch 7/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3916 - loss: 2.1354 - top3_accuracy: 0.6201 - top5_accuracy: 0.7324
# Epoch 7: val_accuracy improved from 0.40768 to 0.41939, saving model to models/effb0_best.keras
#
# Epoch 7: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.4095 - loss: 2.0879 - top3_accuracy: 0.6284 - top5_accuracy: 0.7374 - val_accuracy: 0.4194 - val_loss: 2.1408 - val_top3_accuracy: 0.6182 - val_top5_accuracy: 0.7196 - learning_rate: 1.0000e-05
# Epoch 8/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4005 - loss: 2.1100 - top3_accuracy: 0.6276 - top5_accuracy: 0.7380
# Epoch 8: val_accuracy did not improve from 0.41939
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 88ms/step - accuracy: 0.4133 - loss: 2.0637 - top3_accuracy: 0.6385 - top5_accuracy: 0.7493 - val_accuracy: 0.4154 - val_loss: 2.1419 - val_top3_accuracy: 0.6170 - val_top5_accuracy: 0.7103 - learning_rate: 1.0000e-05
# Epoch 9/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4123 - loss: 2.0993 - top3_accuracy: 0.6233 - top5_accuracy: 0.7289
# Epoch 9: val_accuracy did not improve from 0.41939
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 88ms/step - accuracy: 0.4234 - loss: 2.0501 - top3_accuracy: 0.6370 - top5_accuracy: 0.7465 - val_accuracy: 0.4194 - val_loss: 2.1170 - val_top3_accuracy: 0.6238 - val_top5_accuracy: 0.7244 - learning_rate: 1.0000e-05
# Epoch 10/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4297 - loss: 2.0329 - top3_accuracy: 0.6445 - top5_accuracy: 0.7497
# Epoch 10: val_accuracy improved from 0.41939 to 0.42828, saving model to models/effb0_best.keras
#
# Epoch 10: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.4341 - loss: 2.0057 - top3_accuracy: 0.6521 - top5_accuracy: 0.7558 - val_accuracy: 0.4283 - val_loss: 2.0964 - val_top3_accuracy: 0.6283 - val_top5_accuracy: 0.7277 - learning_rate: 1.0000e-05
# Epoch 11/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4274 - loss: 2.0344 - top3_accuracy: 0.6443 - top5_accuracy: 0.7465
# Epoch 11: val_accuracy improved from 0.42828 to 0.44121, saving model to models/effb0_best.keras
#
# Epoch 11: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.4433 - loss: 1.9858 - top3_accuracy: 0.6566 - top5_accuracy: 0.7609 - val_accuracy: 0.4412 - val_loss: 2.0762 - val_top3_accuracy: 0.6392 - val_top5_accuracy: 0.7269 - learning_rate: 1.0000e-05
# Epoch 12/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4341 - loss: 1.9983 - top3_accuracy: 0.6662 - top5_accuracy: 0.7615
# Epoch 12: val_accuracy did not improve from 0.44121
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.4459 - loss: 1.9599 - top3_accuracy: 0.6708 - top5_accuracy: 0.7678 - val_accuracy: 0.4364 - val_loss: 2.0753 - val_top3_accuracy: 0.6352 - val_top5_accuracy: 0.7269 - learning_rate: 1.0000e-05
# Epoch 13/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4419 - loss: 1.9728 - top3_accuracy: 0.6647 - top5_accuracy: 0.7622
# Epoch 13: val_accuracy did not improve from 0.44121
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.4558 - loss: 1.9260 - top3_accuracy: 0.6794 - top5_accuracy: 0.7749 - val_accuracy: 0.4275 - val_loss: 2.0768 - val_top3_accuracy: 0.6327 - val_top5_accuracy: 0.7236 - learning_rate: 1.0000e-05
# Epoch 14/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4541 - loss: 1.9272 - top3_accuracy: 0.6778 - top5_accuracy: 0.7783
# Epoch 14: val_accuracy improved from 0.44121 to 0.44485, saving model to models/effb0_best.keras
#
# Epoch 14: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 91ms/step - accuracy: 0.4647 - loss: 1.9024 - top3_accuracy: 0.6843 - top5_accuracy: 0.7841 - val_accuracy: 0.4448 - val_loss: 2.0455 - val_top3_accuracy: 0.6465 - val_top5_accuracy: 0.7289 - learning_rate: 1.0000e-05
# Epoch 15/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4592 - loss: 1.9309 - top3_accuracy: 0.6747 - top5_accuracy: 0.7730
# Epoch 15: val_accuracy improved from 0.44485 to 0.45293, saving model to models/effb0_best.keras
#
# Epoch 15: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.4671 - loss: 1.8919 - top3_accuracy: 0.6845 - top5_accuracy: 0.7829 - val_accuracy: 0.4529 - val_loss: 2.0167 - val_top3_accuracy: 0.6533 - val_top5_accuracy: 0.7402 - learning_rate: 1.0000e-05
# Epoch 16/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4656 - loss: 1.8947 - top3_accuracy: 0.6831 - top5_accuracy: 0.7850
# Epoch 16: val_accuracy improved from 0.45293 to 0.45374, saving model to models/effb0_best.keras
#
# Epoch 16: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.4707 - loss: 1.8791 - top3_accuracy: 0.6897 - top5_accuracy: 0.7875 - val_accuracy: 0.4537 - val_loss: 2.0067 - val_top3_accuracy: 0.6549 - val_top5_accuracy: 0.7374 - learning_rate: 1.0000e-05
# Epoch 17/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4610 - loss: 1.9207 - top3_accuracy: 0.6687 - top5_accuracy: 0.7709
# Epoch 17: val_accuracy improved from 0.45374 to 0.45899, saving model to models/effb0_best.keras
#
# Epoch 17: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.4736 - loss: 1.8629 - top3_accuracy: 0.6866 - top5_accuracy: 0.7836 - val_accuracy: 0.4590 - val_loss: 2.0021 - val_top3_accuracy: 0.6549 - val_top5_accuracy: 0.7402 - learning_rate: 1.0000e-05
# Epoch 18/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4768 - loss: 1.8533 - top3_accuracy: 0.6951 - top5_accuracy: 0.7893
# Epoch 18: val_accuracy did not improve from 0.45899
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.4859 - loss: 1.8202 - top3_accuracy: 0.7034 - top5_accuracy: 0.7963 - val_accuracy: 0.4541 - val_loss: 2.0039 - val_top3_accuracy: 0.6521 - val_top5_accuracy: 0.7398 - learning_rate: 1.0000e-05
# Epoch 19/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4922 - loss: 1.8238 - top3_accuracy: 0.7014 - top5_accuracy: 0.7942
# Epoch 19: val_accuracy improved from 0.45899 to 0.46101, saving model to models/effb0_best.keras
#
# Epoch 19: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.4905 - loss: 1.8118 - top3_accuracy: 0.7041 - top5_accuracy: 0.7991 - val_accuracy: 0.4610 - val_loss: 1.9838 - val_top3_accuracy: 0.6545 - val_top5_accuracy: 0.7438 - learning_rate: 1.0000e-05
# Epoch 20/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4839 - loss: 1.8270 - top3_accuracy: 0.6997 - top5_accuracy: 0.7940
# Epoch 20: val_accuracy improved from 0.46101 to 0.46707, saving model to models/effb0_best.keras
#
# Epoch 20: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.4886 - loss: 1.8020 - top3_accuracy: 0.7075 - top5_accuracy: 0.8025 - val_accuracy: 0.4671 - val_loss: 1.9691 - val_top3_accuracy: 0.6683 - val_top5_accuracy: 0.7539 - learning_rate: 1.0000e-05
# Epoch 21/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5000 - loss: 1.7868 - top3_accuracy: 0.7184 - top5_accuracy: 0.8060
# Epoch 21: val_accuracy improved from 0.46707 to 0.47515, saving model to models/effb0_best.keras
#
# Epoch 21: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5082 - loss: 1.7626 - top3_accuracy: 0.7232 - top5_accuracy: 0.8114 - val_accuracy: 0.4752 - val_loss: 1.9421 - val_top3_accuracy: 0.6747 - val_top5_accuracy: 0.7580 - learning_rate: 1.0000e-05
# Epoch 22/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5006 - loss: 1.7740 - top3_accuracy: 0.7146 - top5_accuracy: 0.8033
# Epoch 22: val_accuracy improved from 0.47515 to 0.47596, saving model to models/effb0_best.keras
#
# Epoch 22: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5064 - loss: 1.7459 - top3_accuracy: 0.7229 - top5_accuracy: 0.8138 - val_accuracy: 0.4760 - val_loss: 1.9433 - val_top3_accuracy: 0.6671 - val_top5_accuracy: 0.7527 - learning_rate: 1.0000e-05
# Epoch 23/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5039 - loss: 1.7551 - top3_accuracy: 0.7232 - top5_accuracy: 0.8097
# Epoch 23: val_accuracy improved from 0.47596 to 0.47677, saving model to models/effb0_best.keras
#
# Epoch 23: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5069 - loss: 1.7372 - top3_accuracy: 0.7268 - top5_accuracy: 0.8151 - val_accuracy: 0.4768 - val_loss: 1.9330 - val_top3_accuracy: 0.6731 - val_top5_accuracy: 0.7576 - learning_rate: 1.0000e-05
# Epoch 24/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5060 - loss: 1.7610 - top3_accuracy: 0.7238 - top5_accuracy: 0.8078
# Epoch 24: val_accuracy improved from 0.47677 to 0.48040, saving model to models/effb0_best.keras
#
# Epoch 24: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 91ms/step - accuracy: 0.5174 - loss: 1.7171 - top3_accuracy: 0.7329 - top5_accuracy: 0.8172 - val_accuracy: 0.4804 - val_loss: 1.9272 - val_top3_accuracy: 0.6764 - val_top5_accuracy: 0.7523 - learning_rate: 1.0000e-05
# Epoch 25/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5249 - loss: 1.6958 - top3_accuracy: 0.7300 - top5_accuracy: 0.8223
# Epoch 25: val_accuracy improved from 0.48040 to 0.48444, saving model to models/effb0_best.keras
#
# Epoch 25: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5287 - loss: 1.6818 - top3_accuracy: 0.7378 - top5_accuracy: 0.8268 - val_accuracy: 0.4844 - val_loss: 1.9170 - val_top3_accuracy: 0.6776 - val_top5_accuracy: 0.7592 - learning_rate: 1.0000e-05
# Epoch 26/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5222 - loss: 1.7033 - top3_accuracy: 0.7328 - top5_accuracy: 0.8212
# Epoch 26: val_accuracy improved from 0.48444 to 0.48606, saving model to models/effb0_best.keras
#
# Epoch 26: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5305 - loss: 1.6753 - top3_accuracy: 0.7406 - top5_accuracy: 0.8289 - val_accuracy: 0.4861 - val_loss: 1.9070 - val_top3_accuracy: 0.6780 - val_top5_accuracy: 0.7568 - learning_rate: 1.0000e-05
# Epoch 27/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5243 - loss: 1.6876 - top3_accuracy: 0.7350 - top5_accuracy: 0.8239
# Epoch 27: val_accuracy improved from 0.48606 to 0.49495, saving model to models/effb0_best.keras
#
# Epoch 27: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5362 - loss: 1.6562 - top3_accuracy: 0.7436 - top5_accuracy: 0.8321 - val_accuracy: 0.4949 - val_loss: 1.8866 - val_top3_accuracy: 0.6857 - val_top5_accuracy: 0.7612 - learning_rate: 1.0000e-05
# Epoch 28/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5275 - loss: 1.6687 - top3_accuracy: 0.7398 - top5_accuracy: 0.8255
# Epoch 28: val_accuracy improved from 0.49495 to 0.49657, saving model to models/effb0_best.keras
#
# Epoch 28: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5352 - loss: 1.6490 - top3_accuracy: 0.7431 - top5_accuracy: 0.8283 - val_accuracy: 0.4966 - val_loss: 1.8793 - val_top3_accuracy: 0.6877 - val_top5_accuracy: 0.7572 - learning_rate: 1.0000e-05
# Epoch 29/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5258 - loss: 1.6756 - top3_accuracy: 0.7375 - top5_accuracy: 0.8245
# Epoch 29: val_accuracy did not improve from 0.49657
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 88ms/step - accuracy: 0.5402 - loss: 1.6320 - top3_accuracy: 0.7534 - top5_accuracy: 0.8381 - val_accuracy: 0.4941 - val_loss: 1.8747 - val_top3_accuracy: 0.6877 - val_top5_accuracy: 0.7665 - learning_rate: 1.0000e-05
# Epoch 30/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5448 - loss: 1.6287 - top3_accuracy: 0.7490 - top5_accuracy: 0.8354
# Epoch 30: val_accuracy improved from 0.49657 to 0.50707, saving model to models/effb0_best.keras
#
# Epoch 30: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 88ms/step - accuracy: 0.5481 - loss: 1.6072 - top3_accuracy: 0.7540 - top5_accuracy: 0.8413 - val_accuracy: 0.5071 - val_loss: 1.8527 - val_top3_accuracy: 0.6889 - val_top5_accuracy: 0.7608 - learning_rate: 1.0000e-05
# Epoch 31/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5405 - loss: 1.6235 - top3_accuracy: 0.7472 - top5_accuracy: 0.8348
# Epoch 31: val_accuracy improved from 0.50707 to 0.50869, saving model to models/effb0_best.keras
#
# Epoch 31: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5567 - loss: 1.5838 - top3_accuracy: 0.7598 - top5_accuracy: 0.8452 - val_accuracy: 0.5087 - val_loss: 1.8441 - val_top3_accuracy: 0.6954 - val_top5_accuracy: 0.7648 - learning_rate: 1.0000e-05
# Epoch 32/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5617 - loss: 1.5792 - top3_accuracy: 0.7576 - top5_accuracy: 0.8426
# Epoch 32: val_accuracy improved from 0.50869 to 0.51434, saving model to models/effb0_best.keras
#
# Epoch 32: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5615 - loss: 1.5707 - top3_accuracy: 0.7650 - top5_accuracy: 0.8492 - val_accuracy: 0.5143 - val_loss: 1.8385 - val_top3_accuracy: 0.6945 - val_top5_accuracy: 0.7701 - learning_rate: 1.0000e-05
# Epoch 33/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5554 - loss: 1.5723 - top3_accuracy: 0.7592 - top5_accuracy: 0.8442
# Epoch 33: val_accuracy did not improve from 0.51434
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.5649 - loss: 1.5530 - top3_accuracy: 0.7647 - top5_accuracy: 0.8479 - val_accuracy: 0.5111 - val_loss: 1.8332 - val_top3_accuracy: 0.6949 - val_top5_accuracy: 0.7758 - learning_rate: 1.0000e-05
# Epoch 34/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5598 - loss: 1.5481 - top3_accuracy: 0.7700 - top5_accuracy: 0.8539
# Epoch 34: val_accuracy did not improve from 0.51434
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.5664 - loss: 1.5389 - top3_accuracy: 0.7743 - top5_accuracy: 0.8567 - val_accuracy: 0.5127 - val_loss: 1.8367 - val_top3_accuracy: 0.6966 - val_top5_accuracy: 0.7693 - learning_rate: 1.0000e-05
# Epoch 35/35
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5661 - loss: 1.5497 - top3_accuracy: 0.7691 - top5_accuracy: 0.8471
# Epoch 35: val_accuracy improved from 0.51434 to 0.51879, saving model to models/effb0_best.keras
#
# Epoch 35: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.5686 - loss: 1.5268 - top3_accuracy: 0.7795 - top5_accuracy: 0.8538 - val_accuracy: 0.5188 - val_loss: 1.8204 - val_top3_accuracy: 0.6958 - val_top5_accuracy: 0.7713 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 35.

# %% [markdown]
# ## 7. Графики обучения
#
# Графики позволяют быстро увидеть:
#
# - есть ли переобучение;
# - достигла ли модель плато;
# - помог ли fine-tuning после warmup;
# - не слишком ли большой learning rate.

# %%
def merge_histories(*histories):
    merged = {}
    for history in histories:
        if history is None:
            continue
        for key, values in history.history.items():
            merged.setdefault(key, []).extend(values)
    return merged

def plot_training_curves(history_dict, title="Обучение модели"):
    metrics = [
        ("accuracy", "val_accuracy", "Accuracy"),
        ("top3_accuracy", "val_top3_accuracy", "Top-3 accuracy"),
        ("top5_accuracy", "val_top5_accuracy", "Top-5 accuracy"),
        ("loss", "val_loss", "Loss"),
    ]

    for train_key, val_key, metric_name in metrics:
        if train_key not in history_dict or val_key not in history_dict:
            continue

        plt.figure(figsize=(8, 5))
        plt.plot(history_dict[train_key], label="train")
        plt.plot(history_dict[val_key], label="val")
        plt.title(f"{title}: {metric_name}")
        plt.xlabel("Эпоха")
        plt.ylabel(metric_name)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()

history_all = merge_histories(hist_warmup, hist_ft)
plot_training_curves(history_all, title="EfficientNetB0")

# %%
hist_ft_cont = model_tl.fit(
    train_ds_tl,
    validation_data=val_ds_tl,
    epochs=45,
    initial_epoch=35,
    callbacks=tl_callbacks,
    class_weight=class_weight,
)
# Out:
# Epoch 36/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5812 - loss: 1.4977 - top3_accuracy: 0.7813 - top5_accuracy: 0.8585
# Epoch 36: val_accuracy improved from 0.51879 to 0.52242, saving model to models/effb0_best.keras
#
# Epoch 36: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.5773 - loss: 1.5013 - top3_accuracy: 0.7805 - top5_accuracy: 0.8593 - val_accuracy: 0.5224 - val_loss: 1.8012 - val_top3_accuracy: 0.6966 - val_top5_accuracy: 0.7778 - learning_rate: 1.0000e-05
# Epoch 37/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5669 - loss: 1.5204 - top3_accuracy: 0.7742 - top5_accuracy: 0.8522
# Epoch 37: val_accuracy did not improve from 0.52242
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 86ms/step - accuracy: 0.5747 - loss: 1.4947 - top3_accuracy: 0.7804 - top5_accuracy: 0.8604 - val_accuracy: 0.5208 - val_loss: 1.8083 - val_top3_accuracy: 0.7010 - val_top5_accuracy: 0.7713 - learning_rate: 1.0000e-05
# Epoch 38/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5829 - loss: 1.4888 - top3_accuracy: 0.7910 - top5_accuracy: 0.8639
# Epoch 38: val_accuracy improved from 0.52242 to 0.52768, saving model to models/effb0_best.keras
#
# Epoch 38: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 89ms/step - accuracy: 0.5913 - loss: 1.4646 - top3_accuracy: 0.7972 - top5_accuracy: 0.8697 - val_accuracy: 0.5277 - val_loss: 1.7977 - val_top3_accuracy: 0.7034 - val_top5_accuracy: 0.7758 - learning_rate: 1.0000e-05
# Epoch 39/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5842 - loss: 1.4646 - top3_accuracy: 0.7871 - top5_accuracy: 0.8648
# Epoch 39: val_accuracy improved from 0.52768 to 0.53010, saving model to models/effb0_best.keras
#
# Epoch 39: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.5871 - loss: 1.4613 - top3_accuracy: 0.7893 - top5_accuracy: 0.8661 - val_accuracy: 0.5301 - val_loss: 1.7777 - val_top3_accuracy: 0.7063 - val_top5_accuracy: 0.7798 - learning_rate: 1.0000e-05
# Epoch 40/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5932 - loss: 1.4671 - top3_accuracy: 0.7915 - top5_accuracy: 0.8639
# Epoch 40: val_accuracy did not improve from 0.53010
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 88ms/step - accuracy: 0.5981 - loss: 1.4428 - top3_accuracy: 0.7972 - top5_accuracy: 0.8698 - val_accuracy: 0.5261 - val_loss: 1.7841 - val_top3_accuracy: 0.7026 - val_top5_accuracy: 0.7778 - learning_rate: 1.0000e-05
# Epoch 41/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6009 - loss: 1.4295 - top3_accuracy: 0.8000 - top5_accuracy: 0.8756
# Epoch 41: val_accuracy improved from 0.53010 to 0.53576, saving model to models/effb0_best.keras
#
# Epoch 41: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.6020 - loss: 1.4295 - top3_accuracy: 0.7983 - top5_accuracy: 0.8739 - val_accuracy: 0.5358 - val_loss: 1.7744 - val_top3_accuracy: 0.7046 - val_top5_accuracy: 0.7806 - learning_rate: 1.0000e-05
# Epoch 42/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5984 - loss: 1.4252 - top3_accuracy: 0.7970 - top5_accuracy: 0.8731
# Epoch 42: val_accuracy improved from 0.53576 to 0.53697, saving model to models/effb0_best.keras
#
# Epoch 42: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 34s 91ms/step - accuracy: 0.6057 - loss: 1.4111 - top3_accuracy: 0.8061 - top5_accuracy: 0.8793 - val_accuracy: 0.5370 - val_loss: 1.7688 - val_top3_accuracy: 0.7087 - val_top5_accuracy: 0.7806 - learning_rate: 1.0000e-05
# Epoch 43/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6089 - loss: 1.4012 - top3_accuracy: 0.8039 - top5_accuracy: 0.8721
# Epoch 43: val_accuracy improved from 0.53697 to 0.54586, saving model to models/effb0_best.keras
#
# Epoch 43: finished saving model to models/effb0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 90ms/step - accuracy: 0.6045 - loss: 1.4031 - top3_accuracy: 0.8045 - top5_accuracy: 0.8758 - val_accuracy: 0.5459 - val_loss: 1.7424 - val_top3_accuracy: 0.7135 - val_top5_accuracy: 0.7883 - learning_rate: 1.0000e-05
# Epoch 44/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6040 - loss: 1.4035 - top3_accuracy: 0.8054 - top5_accuracy: 0.8762
# Epoch 44: val_accuracy did not improve from 0.54586
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 32s 88ms/step - accuracy: 0.6079 - loss: 1.3864 - top3_accuracy: 0.8074 - top5_accuracy: 0.8823 - val_accuracy: 0.5426 - val_loss: 1.7436 - val_top3_accuracy: 0.7131 - val_top5_accuracy: 0.7871 - learning_rate: 1.0000e-05
# Epoch 45/45
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6174 - loss: 1.3665 - top3_accuracy: 0.8180 - top5_accuracy: 0.8837
# Epoch 45: val_accuracy did not improve from 0.54586
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 33s 88ms/step - accuracy: 0.6137 - loss: 1.3730 - top3_accuracy: 0.8162 - top5_accuracy: 0.8829 - val_accuracy: 0.5438 - val_loss: 1.7528 - val_top3_accuracy: 0.7111 - val_top5_accuracy: 0.7814 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 43.

# %%
def merge_histories(*histories):
    merged = {}
    for history in histories:
        if history is None:
            continue
        for key, values in history.history.items():
            merged.setdefault(key, []).extend(values)
    return merged

def plot_training_curves(history_dict, title="Обучение модели"):
    metrics = [
        ("accuracy", "val_accuracy", "Accuracy"),
        ("top3_accuracy", "val_top3_accuracy", "Top-3 accuracy"),
        ("top5_accuracy", "val_top5_accuracy", "Top-5 accuracy"),
        ("loss", "val_loss", "Loss"),
    ]

    for train_key, val_key, metric_name in metrics:
        if train_key not in history_dict or val_key not in history_dict:
            continue

        plt.figure(figsize=(8, 5))
        plt.plot(history_dict[train_key], label="train")
        plt.plot(history_dict[val_key], label="val")
        plt.title(f"{title}: {metric_name}")
        plt.xlabel("Эпоха")
        plt.ylabel(metric_name)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()

history_all = merge_histories(hist_warmup, hist_ft, hist_ft_cont)
plot_training_curves(history_all, title="EfficientNetB0")

# %% [markdown]
# ## 8. Оценка на test и подробные метрики
#
# Обычная accuracy не всегда достаточно информативна. Для 33 классов полезны:
#
# - `top-3 accuracy`: правильная марка попала в 3 наиболее вероятных варианта;
# - `top-5 accuracy`: правильная марка попала в 5 вариантов;
# - precision/recall/F1 по каждому классу;
# - confusion matrix.

# %%
best_tl_path = "models/effb0_best.keras"

if os.path.exists(best_tl_path):
    model_tl.load_weights(best_tl_path)
    print("Загружены лучшие веса:", best_tl_path)
else:
    print("Лучший checkpoint не найден, используются текущие веса модели.")

test_metrics = model_tl.evaluate(test_ds_tl, verbose=0)
print("Метрики EfficientNetB0 на test:")
for name, value in zip(model_tl.metrics_names, test_metrics):
    print(f"{name}: {value:.4f}")

y_true = df_test["label_idx"].values
y_pred_proba = model_tl.predict(test_ds_tl, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)

print("\nПроверка top-k через sklearn:")
print("Top-3 accuracy:", top_k_accuracy_score(y_true, y_pred_proba, k=3, labels=np.arange(num_classes)))
print("Top-5 accuracy:", top_k_accuracy_score(y_true, y_pred_proba, k=5, labels=np.arange(num_classes)))

report = classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0,
    output_dict=True,
)
report_df = pd.DataFrame(report).T
display(report_df)
# Out:
# Загружены лучшие веса: models/effb0_best.keras
# Метрики EfficientNetB0 на test:
# loss: 1.7332
# compile_metrics: 0.5374
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step
#
# Проверка top-k через sklearn:
# Top-3 accuracy: 0.7127272727272728
# Top-5 accuracy: 0.7915151515151515
#                precision    recall  f1-score      support
# Acura           0.479452  0.466667  0.472973    75.000000
# Aston Martin    0.633663  0.853333  0.727273    75.000000
# Audi            0.689189  0.680000  0.684564    75.000000
# BMW             0.603774  0.426667  0.500000    75.000000
# Bentley         0.568627  0.773333  0.655367    75.000000
# Buick           0.553571  0.413333  0.473282    75.000000
# Cadillac        0.436508  0.733333  0.547264    75.000000
# Chevrolet       0.552632  0.280000  0.371681    75.000000
# Chrysler        0.712644  0.826667  0.765432    75.000000
# Dodge           0.597222  0.573333  0.585034    75.000000
# FIAT            0.714286  0.800000  0.754717    75.000000
# Ford            0.300000  0.120000  0.171429    75.000000
# GMC             0.626667  0.626667  0.626667    75.000000
# Honda           0.312500  0.266667  0.287770    75.000000
# Hyundai         0.445946  0.440000  0.442953    75.000000
# INFINITI        0.594937  0.626667  0.610390    75.000000
# Jaguar          0.418182  0.306667  0.353846    75.000000
# Jeep            0.696203  0.733333  0.714286    75.000000
# Kia             0.435897  0.226667  0.298246    75.000000
# Land Rover      0.542056  0.773333  0.637363    75.000000
# Lexus           0.500000  0.453333  0.475524    75.000000
# Lincoln         0.464286  0.520000  0.490566    75.000000
# MINI            0.875000  0.840000  0.857143    75.000000
# Mazda           0.513158  0.520000  0.516556    75.000000
# Mercedes-Benz   0.330097  0.453333  0.382022    75.000000
# Mitsubishi      0.390909  0.573333  0.464865    75.000000
# Nissan          0.318182  0.186667  0.235294    75.000000
# Porsche         0.560000  0.560000  0.560000    75.000000
# Ram             0.650943  0.920000  0.762431    75.000000
# Subaru          0.476923  0.413333  0.442857    75.000000
# Toyota          0.369565  0.226667  0.280992    75.000000
# Volkswagen      0.544304  0.573333  0.558442    75.000000
# Volvo           0.518987  0.546667  0.532468    75.000000
# accuracy        0.537374  0.537374  0.537374     0.537374
# macro avg       0.528070  0.537374  0.522415  2475.000000
# weighted avg    0.528070  0.537374  0.522415  2475.000000

# %%
cm = confusion_matrix(y_true, y_pred, labels=np.arange(num_classes))

plt.figure(figsize=(16, 14))
sns.heatmap(
    cm,
    cmap="Blues",
    xticklabels=classes,
    yticklabels=classes,
    square=False,
    cbar=True,
)
plt.title("Confusion matrix на test")
plt.xlabel("Предсказанный класс")
plt.ylabel("Истинный класс")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Нормированная матрица показывает доли ошибок внутри каждого истинного класса.
cm_norm = cm.astype("float") / np.maximum(cm.sum(axis=1, keepdims=True), 1)

plt.figure(figsize=(16, 14))
sns.heatmap(
    cm_norm,
    cmap="Blues",
    xticklabels=classes,
    yticklabels=classes,
    square=False,
    cbar=True,
)
plt.title("Нормированная confusion matrix на test")
plt.xlabel("Предсказанный класс")
plt.ylabel("Истинный класс")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Таблица самых частых пар ошибок.
error_pairs = []
for true_idx in range(num_classes):
    for pred_idx in range(num_classes):
        if true_idx != pred_idx and cm[true_idx, pred_idx] > 0:
            error_pairs.append({
                "true_class": idx2class[true_idx],
                "pred_class": idx2class[pred_idx],
                "count": int(cm[true_idx, pred_idx]),
                "share_within_true_class": float(cm_norm[true_idx, pred_idx]),
            })

error_pairs_df = pd.DataFrame(error_pairs).sort_values(
    ["count", "share_within_true_class"],
    ascending=False,
)
display(error_pairs_df.head(30))
# Out:
#      true_class     pred_class  count  share_within_true_class
# 207       Honda          Acura     12                 0.160000
# 302         Kia        Hyundai     10                 0.133333
# 444      Nissan          Mazda     10                 0.133333
# 275      Jaguar  Mercedes-Benz      9                 0.120000
# 79        Buick       Cadillac      8                 0.106667
# 115   Chevrolet       Cadillac      8                 0.106667
# 203         GMC            Ram      8                 0.106667
# 452     Porsche   Aston Martin      8                 0.106667
# 150       Dodge       Chrysler      7                 0.093333
# 182        Ford            GMC      7                 0.093333
# 308         Kia     Mitsubishi      7                 0.093333
# 349     Lincoln       Cadillac      7                 0.093333
# 37         Audi  Mercedes-Benz      6                 0.080000
# 63          BMW     Volkswagen      6                 0.080000
# 119   Chevrolet           Ford      6                 0.080000
# 120   Chevrolet            GMC      6                 0.080000
# 183        Ford        Hyundai      6                 0.080000
# 190        Ford  Mercedes-Benz      6                 0.080000
# 233     Hyundai          Honda      6                 0.080000
# 261      Jaguar   Aston Martin      6                 0.080000
# 333       Lexus       INFINITI      6                 0.080000
# 424  Mitsubishi     Volkswagen      6                 0.080000
# 505      Toyota     Land Rover      6                 0.080000
# 510      Toyota         Nissan      6                 0.080000
# 511      Toyota            Ram      6                 0.080000
# 4         Acura       Cadillac      5                 0.066667
# 13        Acura     Mitsubishi      5                 0.066667
# 58          BMW  Mercedes-Benz      5                 0.066667
# 187        Ford     Land Rover      5                 0.066667
# 188        Ford        Lincoln      5                 0.066667

# %% [markdown]
# ## 9. Анализ ошибочных предсказаний
#
# Ниже выводятся изображения, где модель ошиблась сильнее всего. Это помогает понять источник проблемы:
#
# - визуально похожие марки;
# - неправильные labels;
# - слишком маленький или закрытый логотип;
# - плохое качество изображения;
# - доменный сдвиг между train и test.

# %%
def show_misclassified_examples(df, y_true, y_pred, y_pred_proba, n=24):
    wrong_idx = np.where(y_true != y_pred)[0]
    if len(wrong_idx) == 0:
        print("Ошибок не найдено.")
        return

    # Уверенность модели в ошибочном предсказании.
    wrong_conf = y_pred_proba[wrong_idx, y_pred[wrong_idx]]
    order = wrong_idx[np.argsort(-wrong_conf)]
    selected = order[:n]

    cols = 4
    rows = int(np.ceil(len(selected) / cols))
    plt.figure(figsize=(4 * cols, 4 * rows))

    for i, idx in enumerate(selected, start=1):
        img = decode_image(df.iloc[idx]["path"]).numpy()

        true_name = idx2class[int(y_true[idx])]
        pred_name = idx2class[int(y_pred[idx])]
        conf = float(y_pred_proba[idx, y_pred[idx]])

        top5 = np.argsort(-y_pred_proba[idx])[:5]
        top5_text = ", ".join([f"{idx2class[int(j)]}: {y_pred_proba[idx, j]:.2f}" for j in top5])

        plt.subplot(rows, cols, i)
        plt.imshow(img)
        plt.axis("off")
        plt.title(f"true: {true_name}\npred: {pred_name} ({conf:.2f})", fontsize=9)
        print(f"{idx}. true={true_name}, pred={pred_name}, top5=[{top5_text}], path={df.iloc[idx]['path']}")

    plt.tight_layout()
    plt.show()

show_misclassified_examples(df_test, y_true, y_pred, y_pred_proba, n=24)
# Out:
# 1237. true=Jaguar, pred=Bentley, top5=[Bentley: 0.97, Aston Martin: 0.01, Jaguar: 0.01, Dodge: 0.00, Ram: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Jaguar/Jaguar_XJ_2010_nan_nan_nan_nan_nan_nan_nan_nan_nan_nan_nan_nan_nan_IIQ.jpg
# 876. true=Ford, pred=Ram, top5=[Ram: 0.97, GMC: 0.02, Chevrolet: 0.00, Ford: 0.00, Dodge: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_F-150_2016_26_17_280_35_6_79_75_209_18_RWD_3_2_Pickup_oPD.jpg
# 1969. true=Nissan, pred=Bentley, top5=[Bentley: 0.96, Mercedes-Benz: 0.02, Cadillac: 0.01, Volvo: 0.00, Chrysler: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Nissan/Nissan_Armada_2012_52_20_310_56_8_79_77_207_13_RWD_8_4_SUV_wHh.jpg
# 851. true=Ford, pred=Ram, top5=[Ram: 0.89, GMC: 0.07, Ford: 0.02, Jeep: 0.01, Toyota: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2013_49_18_380_62_8_79_77_nan_nan_RWD_5_4_Pickup_Obg.jpg
# 2294. true=Toyota, pred=Cadillac, top5=[Cadillac: 0.89, Lincoln: 0.01, Chrysler: 0.01, Mazda: 0.01, Volkswagen: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Toyota/Toyota_Avalon_2013_39_18_260_35_6_72_57_195_nan_FWD_5_4_4dr_nty.jpg
# 1847. true=Mercedes-Benz, pred=Bentley, top5=[Bentley: 0.86, Mercedes-Benz: 0.04, Volvo: 0.03, Jaguar: 0.03, BMW: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Mercedes-Benz/Mercedes-Benz_E Class_2017_72_19_390_30_6_73_57_194_18_AWD_5_4_4dr_FwS.jpg
# 2267. true=Toyota, pred=Ram, top5=[Ram: 0.85, GMC: 0.04, Cadillac: 0.02, Ford: 0.02, Chevrolet: 0.02], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Toyota/Toyota_Tundra_2011_29_18_310_46_8_79_75_nan_15_RWD_6_4_Pickup_YNf.jpg
# 239. true=BMW, pred=Lincoln, top5=[Lincoln: 0.85, Volvo: 0.03, BMW: 0.03, Porsche: 0.01, Cadillac: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/BMW/BMW_X6_2019_63_19_300_30_6_78_67_193_18_RWD_5_4_SUV_DPQ.jpg
# 1071. true=Hyundai, pred=Subaru, top5=[Subaru: 0.84, Hyundai: 0.04, Kia: 0.02, Lexus: 0.01, Toyota: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Hyundai/Hyundai_Veloster_2013_21_18_130_16_4_70_55_166_28_FWD_4_3_2dr_FMV.jpg
# 2050. true=Porsche, pred=Aston Martin, top5=[Aston Martin: 0.83, Jaguar: 0.07, Porsche: 0.05, Dodge: 0.01, Bentley: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Porsche/Porsche_911_2017_108_19_370_30_6_72_50_177_19_AWD_4_2_Convertible_nix.jpg
# 622. true=Chrysler, pred=Cadillac, top5=[Cadillac: 0.82, Chrysler: 0.09, Audi: 0.01, Volkswagen: 0.01, Chevrolet: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chrysler/Chrysler_300_2016_41_19_290_36_6_75_59_198_18_AWD_5_4_4dr_Qkj.jpg
# 617. true=Chrysler, pred=Cadillac, top5=[Cadillac: 0.82, Chrysler: 0.05, Chevrolet: 0.02, GMC: 0.01, Volvo: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chrysler/Chrysler_300_2017_41_19_290_36_6_75_59_198_18_AWD_5_4_4dr_wOl.jpg
# 899. true=Ford, pred=GMC, top5=[GMC: 0.82, Ram: 0.13, Chevrolet: 0.02, Nissan: 0.02, Toyota: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2016_52_18_380_62_8_79_77_246_nan_RWD_5_4_Pickup_dMm.jpg
# 854. true=Ford, pred=GMC, top5=[GMC: 0.81, Nissan: 0.09, Ram: 0.06, Chevrolet: 0.01, Ford: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2012_47_18_380_62_8_79_77_nan_nan_RWD_5_4_Pickup_our.jpg
# 1233. true=Jaguar, pred=Aston Martin, top5=[Aston Martin: 0.81, Jaguar: 0.14, Porsche: 0.03, Audi: 0.01, Mercedes-Benz: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Jaguar/Jaguar_F-Type_2017_66_18_340_30_6_75_51_176_20_RWD_2_2_Convertible_rjI.jpg
# 826. true=Ford, pred=Ram, top5=[Ram: 0.80, Chevrolet: 0.11, GMC: 0.05, Ford: 0.01, Cadillac: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_F-150_2017_51_18_380_50_8_79_75_231_15_RWD_5_4_Pickup_uVQ.jpg
# 38. true=Acura, pred=Mitsubishi, top5=[Mitsubishi: 0.80, Honda: 0.02, Audi: 0.02, INFINITI: 0.02, Land Rover: 0.02], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Acura/Acura_MDX_2014_42_18_290_35_6_77_67_193_20_FWD_7_4_SUV_XXG.jpg
# 1353. true=Kia, pred=Mitsubishi, top5=[Mitsubishi: 0.79, Kia: 0.09, FIAT: 0.02, Chrysler: 0.02, Toyota: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Kia/Kia_Sorento_2011_21_17_170_24_4_74_67_183_20_FWD_5_4_SUV_TJi.jpg
# 890. true=Ford, pred=Land Rover, top5=[Land Rover: 0.79, Ford: 0.10, Volkswagen: 0.04, Lincoln: 0.01, Dodge: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Flex_2010_39_19_260_35_6_75_68_201_16_AWD_7_4_4dr_Rwo.jpg
# 887. true=Ford, pred=GMC, top5=[GMC: 0.79, Lincoln: 0.03, Ford: 0.03, Ram: 0.03, Mitsubishi: 0.03], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_F-150_2013_27_17_300_37_6_79_74_nan_17_RWD_3_2_Pickup_EkZ.jpg
# 905. true=GMC, pred=Ram, top5=[Ram: 0.79, GMC: 0.14, Chevrolet: 0.04, Ford: 0.01, Toyota: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/GMC/GMC_Sierra 1500_2013_46_20_400_62_8_80_73_nan_13_RWD_5_4_Pickup_Wez.jpg
# 1512. true=Lexus, pred=Bentley, top5=[Bentley: 0.78, Land Rover: 0.16, Jaguar: 0.01, Lexus: 0.01, Audi: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Lexus/Lexus_GX_2019_52_18_300_46_8_74_74_189_15_4WD_7_4_SUV_QwC.jpg
# 963. true=GMC, pred=Land Rover, top5=[Land Rover: 0.78, GMC: 0.13, Chevrolet: 0.03, Cadillac: 0.01, MINI: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/GMC/GMC_Yukon_2014_58_20_400_62_8_79_76_nan_14_RWD_7_4_SUV_HMp.jpg
# 992. true=Honda, pred=Aston Martin, top5=[Aston Martin: 0.78, Jaguar: 0.05, BMW: 0.04, Lexus: 0.03, Mercedes-Benz: 0.02], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Honda/Honda_Accord_2011_25_17_190_24_4_72_56_191_22_FWD_5_2_2dr_ZTj.jpg

# %% [markdown]
# ## 10. Идеи следующих экспериментов
#
# На основе текущего качества около 44% accuracy для EfficientNetB0, наиболее перспективные направления:
#
# 1. **Проверить датасет**: дубликаты, ошибки разметки, слишком похожие классы, дисбаланс.
# 2. **Использовать большее разрешение**: `260×260` или `300×300`, потому что различия между марками часто мелкие.
# 3. **Попробовать backbone сильнее**: EfficientNetB2/B3, ConvNeXtTiny, ResNet50V2.
# 4. **Дольше обучать classifier head**: 10–20 эпох до fine-tuning.
# 5. **Размораживать backbone постепенно**: например 40 → 80 → 120 верхних слоёв с LR `1e-5`, затем `3e-6`.
# 6. **Использовать MixUp/CutMix**: может повысить устойчивость, особенно при малом датасете.
# 7. **Смотреть top-5 accuracy**: для задачи из 33 марок top-5 часто показывает, умеет ли модель сужать выбор до похожих вариантов.
# 8. **Анализировать ошибки по классам**: если отдельные классы почти не распознаются, нужны дополнительные изображения или очистка labels.
#
# Главный практический шаг после запуска этого ноутбука — изучить `classification_report`, confusion matrix и изображения ошибочных предсказаний. Именно они подскажут, что даст больший прирост: данные, архитектура или режим fine-tuning.
