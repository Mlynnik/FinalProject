# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf

print("Версия TensorFlow:", tf.__version__)
print("Доступные GPU:", tf.config.list_physical_devices('GPU'))
tf.config.set_visible_devices(tf.config.list_physical_devices('GPU')[0], 'GPU')
# Out:
# Версия TensorFlow: 2.21.0
# Доступные GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2B0, preprocess_input
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    CSVLogger,
)

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score, accuracy_score

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = (224, 224)
BATCH_SIZE = 64
AUTO = tf.data.AUTOTUNE

DATA_DIR = Path("/home/sm/Desktop/ml/CarBrandClassificationDataset")

EPOCHS_WARMUP = 12
EPOCHS_FINETUNE = 12

AUTO = tf.data.AUTOTUNE

MODEL_DIR = Path("models")
MODEL_DIR.mkdir(exist_ok=True)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# ## 1. Загрузка структуры датасета
#
# Ожидается структура:
#
# ```text
# CarBrandClassificationDataset/
# ├── train/
# │   ├── class_1/
# │   └── ...
# ├── val/
# │   ├── class_1/
# │   └── ...
# └── test/
#     ├── class_1/
#     └── ...
# ```
#
# В таблицы ниже собираются пути к изображениям и строковые метки классов.

# %%
train_base = DATA_DIR / "train"
val_base = DATA_DIR / "val"
test_base = DATA_DIR / "test"

IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

def build_split_df(split_dir: Path) -> pd.DataFrame:
    """Собирает таблицу path/label для одного split'а."""
    if not split_dir.exists():
        raise FileNotFoundError(f"Папка split'а не найдена: {split_dir}")

    rows = []
    class_dirs = sorted([d for d in split_dir.iterdir() if d.is_dir()])
    for cls_dir in class_dirs:
        cls = cls_dir.name
        for f in cls_dir.rglob("*"):
            if f.is_file() and f.suffix.lower() in IMAGE_EXTENSIONS:
                rows.append((str(f), cls))
    return pd.DataFrame(rows, columns=["path", "label"])

df_train = build_split_df(train_base)
df_val = build_split_df(val_base)
df_test = build_split_df(test_base)

print("Количество изображений:")
print("Train:", len(df_train), "| классов:", df_train["label"].nunique())
print("Val  :", len(df_val), "| классов:", df_val["label"].nunique())
print("Test :", len(df_test), "| классов:", df_test["label"].nunique())

display(pd.concat({
    "train": df_train["label"].value_counts().sort_index(),
    "val": df_val["label"].value_counts().sort_index(),
    "test": df_test["label"].value_counts().sort_index(),
}, axis=1).fillna(0).astype(int).head())
# Out:
# Количество изображений:
# Train: 11517 | классов: 33
# Val  : 2475 | классов: 33
# Test : 2475 | классов: 33
#               train  val  test
# label
# Acura           349   75    75
# Aston Martin    349   75    75
# Audi            349   75    75
# BMW             349   75    75
# Bentley         349   75    75

# %%
# Единое отображение классов в индексы.
classes = sorted(df_train["label"].unique().tolist())
class2idx = {c: i for i, c in enumerate(classes)}
idx2class = {i: c for c, i in class2idx.items()}
num_classes = len(classes)

for name, df in [("val", df_val), ("test", df_test)]:
    missing = set(df["label"].unique()) - set(classes)
    if missing:
        raise ValueError(f"В {name} есть классы, которых нет в train: {sorted(missing)}")

df_train["label_idx"] = df_train["label"].map(class2idx)
df_val["label_idx"] = df_val["label"].map(class2idx)
df_test["label_idx"] = df_test["label"].map(class2idx)

print("Число классов:", num_classes)
print("Пример отображения:", list(class2idx.items())[:10])
df_train.head()
# Out:
# Число классов: 33
# Пример отображения: [('Acura', 0), ('Aston Martin', 1), ('Audi', 2), ('BMW', 3), ('Bentley', 4), ('Buick', 5), ('Cadillac', 6), ('Chevrolet', 7), ('Chrysler', 8), ('Dodge', 9)]
#                                                 path  label  label_idx
# 0  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 1  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 2  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 3  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 4  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0

# %% [markdown]
# ## 2. Распределение изображений по классам
#
# равномерное распределение по всем классам

# %%
def plot_class_distribution(df: pd.DataFrame, title: str) -> None:
    counts = df["label"].value_counts().sort_values(ascending=False)
    plt.figure(figsize=(14, 5))
    sns.barplot(x=counts.index, y=counts.values)
    plt.title(title)
    plt.xlabel("Класс")
    plt.ylabel("Количество изображений")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

plot_class_distribution(df_train, "Распределение классов в train")
plot_class_distribution(df_val, "Распределение классов в val")
plot_class_distribution(df_test, "Распределение классов в test")

class_counts = df_train["label_idx"].value_counts().sort_index()
imbalance_ratio = class_counts.max() / max(class_counts.min(), 1)
print(f"Коэффициент дисбаланса train max/min: {imbalance_ratio:.2f}")
# Out:
# Коэффициент дисбаланса train max/min: 1.00

# %% [markdown]
# ## 3. `tf.data`-пайплайн и аугментация
#
# Используется resize_with_pad, т.к. для авто критичны пропорции (resize) и нельзя обрезать (crop) - мы рискуем потерять важную часть изображения
#
# Для EfficientNet используется совместимый с ImageNet-предобучением `preprocess_input`(взял из примера, в доках прочитал, что это уже фунция заглушка, функционал встроен в модель).

# %%
def decode_image(path):
    """Читает изображение, приводит к RGB, float32 и нужному размеру."""
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize_with_pad(img, IMG_SIZE[0], IMG_SIZE[1])
    return img

augmenter = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.08, 0.08),
    layers.RandomContrast(0.15),
], name="augmenter")

def make_ds(paths, labels, augment=False, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    if shuffle:
        ds = ds.shuffle(min(len(paths), 4096), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(lambda x, y: (decode_image(x), y), num_parallel_calls=AUTO)
    ds = ds.cache()

    if augment:
        ds = ds.map(lambda x, y: (augmenter(x, training=True),y), num_parallel_calls=AUTO)

    ds = ds.map(lambda x, y: (preprocess_input(x * 255.0),y),num_parallel_calls=AUTO)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(AUTO)

    return ds

train_ds = make_ds(
    df_train["path"].tolist(),
    df_train["label_idx"].tolist(),
    augment=True,
    shuffle=True,
)

val_ds = make_ds(
    df_val["path"].tolist(),
    df_val["label_idx"].tolist(),
)

test_ds = make_ds(
    df_test["path"].tolist(),
    df_test["label_idx"].tolist(),
)

print(train_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## 4. Transfer learning: EfficientNetB0V2
#
# используем предобученную на других данных модель для решения нашей задачи
#
# сначала подбор гиперпараметров, нормальный gridsearch строить не стал, потому что этот полчаса отрабатывал полный перебор с нормальным количеством вариаций может и дал бы небольшой прирост, но за сутки ноут бы сдох

# %%
search_space = [

    {
        "dropout": 0.25,
        "dense_units": 128,
        "lr": 3e-4,
    },

    {
        "dropout": 0.35,
        "dense_units": 256,
        "lr": 3e-4,
    },

    {
        "dropout": 0.40,
        "dense_units": 256,
        "lr": 1e-4,
    },

    {
        "dropout": 0.35,
        "dense_units": 512,
        "lr": 3e-4,
    },

    {
        "dropout": 0.4,
        "dense_units": 512,
        "lr": 3e-4,
    },
]

def build_model(dropout,dense_units,lr):
    base_model = EfficientNetV2B0(
        include_top=False,
        weights="imagenet",
        input_shape=IMG_SIZE + (3,),
    )

    base_model.trainable = False
    inputs = layers.Input(shape=IMG_SIZE + (3,))
    x = base_model(inputs,training=False)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units,activation="relu",)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout * 0.75)(x)

    outputs = layers.Dense(
        num_classes,
        activation="softmax",
        dtype="float32",
    )(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=[
            "accuracy",
            tf.keras.metrics.SparseTopKCategoricalAccuracy(
                k=5,
                name="top5_acc",
            ),
        ],
    )

    return model

# %%
search_results = []

best_model = None
best_val_acc = 0.0

for i, config in enumerate(search_space):

    print("=" * 60)
    print(f"CONFIG {i+1}/{len(search_space)}")
    print(config)

    model_hp = build_model(
        dropout=config["dropout"],
        dense_units=config["dense_units"],
        lr=config["lr"],
    )

    history_hp = model_hp.fit(
        train_ds,
        validation_data=val_ds,
        epochs=5,
        verbose=1,
    )

    best_epoch_acc = max(
        history_hp.history["val_accuracy"]
    )

    search_results.append({
        **config,
        "val_accuracy": best_epoch_acc,
    })

    print(f"Best val_accuracy: {best_epoch_acc:.4f}")

    if best_epoch_acc > best_val_acc:
        best_val_acc = best_epoch_acc
        best_model = model_hp

print("\nBEST VAL ACC:", best_val_acc)
# Out:
# ============================================================
# CONFIG 1/5
# {'dropout': 0.25, 'dense_units': 128, 'lr': 0.0003}
# Epoch 1/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 86s 336ms/step - accuracy: 0.0643 - loss: 3.9240 - top5_acc: 0.2262 - val_accuracy: 0.1034 - val_loss: 3.2939 - val_top5_acc: 0.3523
# Epoch 2/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.1011 - loss: 3.4755 - top5_acc: 0.3288 - val_accuracy: 0.1495 - val_loss: 3.1149 - val_top5_acc: 0.4226
# Epoch 3/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.1295 - loss: 3.2819 - top5_acc: 0.3799 - val_accuracy: 0.1717 - val_loss: 3.0053 - val_top5_acc: 0.4651
# Epoch 4/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - accuracy: 0.1584 - loss: 3.1549 - top5_acc: 0.4194 - val_accuracy: 0.1992 - val_loss: 2.9085 - val_top5_acc: 0.5083
# Epoch 5/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.1760 - loss: 3.0496 - top5_acc: 0.4564 - val_accuracy: 0.2202 - val_loss: 2.8425 - val_top5_acc: 0.5281
# Best val_accuracy: 0.2202
# ============================================================
# CONFIG 2/5
# {'dropout': 0.35, 'dense_units': 256, 'lr': 0.0003}
# Epoch 1/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 57s 226ms/step - accuracy: 0.0656 - loss: 4.0647 - top5_acc: 0.2278 - val_accuracy: 0.1099 - val_loss: 3.2558 - val_top5_acc: 0.3442
# Epoch 2/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.1060 - loss: 3.5644 - top5_acc: 0.3347 - val_accuracy: 0.1693 - val_loss: 3.0419 - val_top5_acc: 0.4457
# Epoch 3/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 113ms/step - accuracy: 0.1401 - loss: 3.2993 - top5_acc: 0.3999 - val_accuracy: 0.1992 - val_loss: 2.9137 - val_top5_acc: 0.4954
# Epoch 4/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.1641 - loss: 3.1550 - top5_acc: 0.4344 - val_accuracy: 0.2275 - val_loss: 2.8258 - val_top5_acc: 0.5325
# Epoch 5/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.1767 - loss: 3.0632 - top5_acc: 0.4610 - val_accuracy: 0.2319 - val_loss: 2.7854 - val_top5_acc: 0.5543
# Best val_accuracy: 0.2319
# ============================================================
# CONFIG 3/5
# {'dropout': 0.4, 'dense_units': 256, 'lr': 0.0001}
# Epoch 1/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 51s 202ms/step - accuracy: 0.0404 - loss: 4.3824 - top5_acc: 0.1786 - val_accuracy: 0.0840 - val_loss: 3.4650 - val_top5_acc: 0.2691
# Epoch 2/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.0648 - loss: 4.0521 - top5_acc: 0.2395 - val_accuracy: 0.1103 - val_loss: 3.3067 - val_top5_acc: 0.3527
# Epoch 3/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.0750 - loss: 3.8760 - top5_acc: 0.2764 - val_accuracy: 0.1333 - val_loss: 3.2051 - val_top5_acc: 0.3875
# Epoch 4/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 117ms/step - accuracy: 0.0873 - loss: 3.7326 - top5_acc: 0.3024 - val_accuracy: 0.1511 - val_loss: 3.1308 - val_top5_acc: 0.4145
# Epoch 5/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 113ms/step - accuracy: 0.0965 - loss: 3.6062 - top5_acc: 0.3260 - val_accuracy: 0.1616 - val_loss: 3.0683 - val_top5_acc: 0.4420
# Best val_accuracy: 0.1616
# ============================================================
# CONFIG 4/5
# {'dropout': 0.35, 'dense_units': 512, 'lr': 0.0003}
# Epoch 1/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 55s 209ms/step - accuracy: 0.0819 - loss: 3.9989 - top5_acc: 0.2746 - val_accuracy: 0.1333 - val_loss: 3.1539 - val_top5_acc: 0.4032
# Epoch 2/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.1366 - loss: 3.4603 - top5_acc: 0.3757 - val_accuracy: 0.1851 - val_loss: 2.9432 - val_top5_acc: 0.4958
# Epoch 3/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - accuracy: 0.1617 - loss: 3.2221 - top5_acc: 0.4391 - val_accuracy: 0.2222 - val_loss: 2.8597 - val_top5_acc: 0.5208
# Epoch 4/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.1922 - loss: 3.0443 - top5_acc: 0.4823 - val_accuracy: 0.2505 - val_loss: 2.7525 - val_top5_acc: 0.5507
# Epoch 5/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - accuracy: 0.2093 - loss: 2.9379 - top5_acc: 0.5123 - val_accuracy: 0.2727 - val_loss: 2.6796 - val_top5_acc: 0.5826
# Best val_accuracy: 0.2727
# ============================================================
# CONFIG 5/5
# {'dropout': 0.4, 'dense_units': 512, 'lr': 0.0003}
# Epoch 1/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 52s 207ms/step - accuracy: 0.0778 - loss: 4.0673 - top5_acc: 0.2595 - val_accuracy: 0.1216 - val_loss: 3.1655 - val_top5_acc: 0.3988
# Epoch 2/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.1256 - loss: 3.5235 - top5_acc: 0.3732 - val_accuracy: 0.1915 - val_loss: 2.9406 - val_top5_acc: 0.4881
# Epoch 3/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.1507 - loss: 3.2919 - top5_acc: 0.4239 - val_accuracy: 0.2077 - val_loss: 2.8685 - val_top5_acc: 0.5143
# Epoch 4/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.1789 - loss: 3.1260 - top5_acc: 0.4598 - val_accuracy: 0.2380 - val_loss: 2.7594 - val_top5_acc: 0.5547
# Epoch 5/5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.1961 - loss: 3.0243 - top5_acc: 0.4952 - val_accuracy: 0.2481 - val_loss: 2.7062 - val_top5_acc: 0.5737
# Best val_accuracy: 0.2481
#
# BEST VAL ACC: 0.27272728085517883

# %%
results_hp_df = pd.DataFrame(
    search_results
)

results_hp_df = results_hp_df.sort_values(
    by="val_accuracy",
    ascending=False,
)

results_hp_df
# Out:
#    dropout  dense_units      lr  val_accuracy
# 3     0.35          512  0.0003      0.272727
# 4     0.40          512  0.0003      0.248081
# 1     0.35          256  0.0003      0.231919
# 0     0.25          128  0.0003      0.220202
# 2     0.40          256  0.0001      0.161616

# %%
best_config = results_hp_df.iloc[0]
best_config
# Out:
# dropout           0.350000
# dense_units     512.000000
# lr                0.000300
# val_accuracy      0.272727
# Name: 3, dtype: float64

# %% [markdown]
# забил параметры руками, чтобы спокойно перезапускать

# %%
def build_efficientnet(num_classes: int, img_size=IMG_SIZE, dropout=0.35, dense_units=512) -> tuple[tf.keras.Model, tf.keras.Model]:
    base = EfficientNetV2B0(
        include_top=False,
        weights="imagenet",
        input_shape=(*img_size, 3),
    )
    base.trainable = False

    inputs = layers.Input(shape=(*img_size, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Dense(dense_units, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout * 0.75)(x)

    logits = layers.Dense(num_classes)(x)
    outputs = layers.Activation("softmax", dtype="float32")(logits)

    model = models.Model(inputs, outputs, name="efficientnetb0_car_brand")
    return model, base

def compile_model(model: tf.keras.Model, lr: float) -> None:
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="sparse_categorical_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top3_accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_accuracy"),
        ],
    )

model_tl, base = build_efficientnet(num_classes)
compile_model(model_tl, lr=3e-4)
model_tl.summary()
# Out:
# Model: "efficientnetb0_car_brand"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 7, 7, 1280)     │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 33)             │        16,929 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 33)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,599,281 (25.17 MB)
#  Trainable params: 676,385 (2.58 MB)
#  Non-trainable params: 5,922,896 (22.59 MB)

# %% [markdown]
# обучение классификатора на фиксированных признаках
#
# так как мы используем предобученную модель, то я замораживаю исходные слои, добавил свои и обучаю пока только их

# %%
tl_callbacks = [
    ModelCheckpoint(
        "models/effv2b0_best.keras",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=1,
    ),
    EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=6,
        restore_best_weights=True,
        verbose=1,
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-7,
        verbose=1,
    ),
    CSVLogger("models/effv2b0_training_log.csv", append=False),
]

print("Этап 1: обучение classifier head при замороженном backbone.")
hist_warmup = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_WARMUP,
    callbacks=tl_callbacks,
)
# Out:
# Этап 1: обучение classifier head при замороженном backbone.
# Epoch 1/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.0655 - loss: 4.1883 - top3_accuracy: 0.1640 - top5_accuracy: 0.2466
# Epoch 1: val_accuracy improved from None to 0.14586, saving model to models/effv2b0_best.keras
#
# Epoch 1: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 85s 326ms/step - accuracy: 0.0788 - loss: 4.0098 - top3_accuracy: 0.1835 - top5_accuracy: 0.2711 - val_accuracy: 0.1459 - val_loss: 3.1502 - val_top3_accuracy: 0.3143 - val_top5_accuracy: 0.4182 - learning_rate: 3.0000e-04
# Epoch 2/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.1150 - loss: 3.5233 - top3_accuracy: 0.2615 - top5_accuracy: 0.3649
# Epoch 2: val_accuracy improved from 0.14586 to 0.17657, saving model to models/effv2b0_best.keras
#
# Epoch 2: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.1320 - loss: 3.4585 - top3_accuracy: 0.2758 - top5_accuracy: 0.3772 - val_accuracy: 0.1766 - val_loss: 2.9467 - val_top3_accuracy: 0.3701 - val_top5_accuracy: 0.5071 - learning_rate: 3.0000e-04
# Epoch 3/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.1530 - loss: 3.2814 - top3_accuracy: 0.3177 - top5_accuracy: 0.4302
# Epoch 3: val_accuracy improved from 0.17657 to 0.21091, saving model to models/effv2b0_best.keras
#
# Epoch 3: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - accuracy: 0.1659 - loss: 3.2228 - top3_accuracy: 0.3302 - top5_accuracy: 0.4389 - val_accuracy: 0.2109 - val_loss: 2.8387 - val_top3_accuracy: 0.4210 - val_top5_accuracy: 0.5337 - learning_rate: 3.0000e-04
# Epoch 4/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.1770 - loss: 3.1023 - top3_accuracy: 0.3547 - top5_accuracy: 0.4677
# Epoch 4: val_accuracy improved from 0.21091 to 0.24646, saving model to models/effv2b0_best.keras
#
# Epoch 4: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.1908 - loss: 3.0605 - top3_accuracy: 0.3634 - top5_accuracy: 0.4784 - val_accuracy: 0.2465 - val_loss: 2.7381 - val_top3_accuracy: 0.4457 - val_top5_accuracy: 0.5685 - learning_rate: 3.0000e-04
# Epoch 5/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.1999 - loss: 2.9824 - top3_accuracy: 0.3889 - top5_accuracy: 0.5064
# Epoch 5: val_accuracy improved from 0.24646 to 0.26909, saving model to models/effv2b0_best.keras
#
# Epoch 5: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 117ms/step - accuracy: 0.2102 - loss: 2.9473 - top3_accuracy: 0.3942 - top5_accuracy: 0.5129 - val_accuracy: 0.2691 - val_loss: 2.6664 - val_top3_accuracy: 0.4646 - val_top5_accuracy: 0.5846 - learning_rate: 3.0000e-04
# Epoch 6/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.2232 - loss: 2.8690 - top3_accuracy: 0.4224 - top5_accuracy: 0.5389
# Epoch 6: val_accuracy improved from 0.26909 to 0.27030, saving model to models/effv2b0_best.keras
#
# Epoch 6: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 117ms/step - accuracy: 0.2315 - loss: 2.8248 - top3_accuracy: 0.4243 - top5_accuracy: 0.5452 - val_accuracy: 0.2703 - val_loss: 2.6338 - val_top3_accuracy: 0.4756 - val_top5_accuracy: 0.5935 - learning_rate: 3.0000e-04
# Epoch 7/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2353 - loss: 2.8242 - top3_accuracy: 0.4344 - top5_accuracy: 0.5475
# Epoch 7: val_accuracy improved from 0.27030 to 0.28848, saving model to models/effv2b0_best.keras
#
# Epoch 7: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - accuracy: 0.2502 - loss: 2.7639 - top3_accuracy: 0.4473 - top5_accuracy: 0.5612 - val_accuracy: 0.2885 - val_loss: 2.5639 - val_top3_accuracy: 0.5022 - val_top5_accuracy: 0.6226 - learning_rate: 3.0000e-04
# Epoch 8/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2461 - loss: 2.7305 - top3_accuracy: 0.4540 - top5_accuracy: 0.5775
# Epoch 8: val_accuracy improved from 0.28848 to 0.30545, saving model to models/effv2b0_best.keras
#
# Epoch 8: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - accuracy: 0.2646 - loss: 2.6772 - top3_accuracy: 0.4672 - top5_accuracy: 0.5865 - val_accuracy: 0.3055 - val_loss: 2.5287 - val_top3_accuracy: 0.5127 - val_top5_accuracy: 0.6299 - learning_rate: 3.0000e-04
# Epoch 9/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2670 - loss: 2.6783 - top3_accuracy: 0.4717 - top5_accuracy: 0.5921
# Epoch 9: val_accuracy did not improve from 0.30545
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 113ms/step - accuracy: 0.2709 - loss: 2.6426 - top3_accuracy: 0.4786 - top5_accuracy: 0.5969 - val_accuracy: 0.3022 - val_loss: 2.5149 - val_top3_accuracy: 0.5164 - val_top5_accuracy: 0.6311 - learning_rate: 3.0000e-04
# Epoch 10/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2734 - loss: 2.6394 - top3_accuracy: 0.4775 - top5_accuracy: 0.6010
# Epoch 10: val_accuracy improved from 0.30545 to 0.31071, saving model to models/effv2b0_best.keras
#
# Epoch 10: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.2841 - loss: 2.5915 - top3_accuracy: 0.4903 - top5_accuracy: 0.6132 - val_accuracy: 0.3107 - val_loss: 2.4853 - val_top3_accuracy: 0.5277 - val_top5_accuracy: 0.6372 - learning_rate: 3.0000e-04
# Epoch 11/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2824 - loss: 2.5894 - top3_accuracy: 0.4929 - top5_accuracy: 0.6161
# Epoch 11: val_accuracy did not improve from 0.31071
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.2915 - loss: 2.5569 - top3_accuracy: 0.5052 - top5_accuracy: 0.6211 - val_accuracy: 0.3042 - val_loss: 2.4648 - val_top3_accuracy: 0.5410 - val_top5_accuracy: 0.6412 - learning_rate: 3.0000e-04
# Epoch 12/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2901 - loss: 2.5655 - top3_accuracy: 0.5037 - top5_accuracy: 0.6146
# Epoch 12: val_accuracy improved from 0.31071 to 0.33253, saving model to models/effv2b0_best.keras
#
# Epoch 12: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 118ms/step - accuracy: 0.3042 - loss: 2.5087 - top3_accuracy: 0.5147 - top5_accuracy: 0.6257 - val_accuracy: 0.3325 - val_loss: 2.4200 - val_top3_accuracy: 0.5491 - val_top5_accuracy: 0.6610 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# fine-tuning - разморозил часть исходных слоев, для дообучения

# %%
def set_fine_tuning(base_model: tf.keras.Model, fine_tune_layers: int) -> None:
    """Размораживает последние fine_tune_layers слоёв, кроме BatchNormalization."""
    base_model.trainable = True

    for layer in base_model.layers[:-fine_tune_layers]:
        layer.trainable = False

    for layer in base_model.layers:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

FINE_TUNE_LAYERS = 80
set_fine_tuning(base, fine_tune_layers=FINE_TUNE_LAYERS)

trainable_count = sum(int(layer.trainable) for layer in base.layers)
print(f"Trainable слоёв backbone: {trainable_count} из {len(base.layers)}")

compile_model(model_tl, lr=1e-4)

print("Этап 2: fine-tuning верхних слоёв EfficientNetV2B0.")
hist_ft = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_FINETUNE,
    callbacks=tl_callbacks,
)
# Out:
# Trainable слоёв backbone: 64 из 270
# Этап 2: fine-tuning верхних слоёв EfficientNetV2B0.
# Epoch 1/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.3165 - loss: 2.4381 - top3_accuracy: 0.5378 - top5_accuracy: 0.6594
# Epoch 1: val_accuracy improved from 0.33253 to 0.38020, saving model to models/effv2b0_best.keras
#
# Epoch 1: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 58s 228ms/step - accuracy: 0.3375 - loss: 2.3634 - top3_accuracy: 0.5582 - top5_accuracy: 0.6725 - val_accuracy: 0.3802 - val_loss: 2.2759 - val_top3_accuracy: 0.5935 - val_top5_accuracy: 0.6873 - learning_rate: 1.0000e-04
# Epoch 2/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3688 - loss: 2.2499 - top3_accuracy: 0.5930 - top5_accuracy: 0.7064
# Epoch 2: val_accuracy improved from 0.38020 to 0.40121, saving model to models/effv2b0_best.keras
#
# Epoch 2: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.3794 - loss: 2.1990 - top3_accuracy: 0.6035 - top5_accuracy: 0.7140 - val_accuracy: 0.4012 - val_loss: 2.1808 - val_top3_accuracy: 0.6117 - val_top5_accuracy: 0.7099 - learning_rate: 1.0000e-04
# Epoch 3/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4052 - loss: 2.1115 - top3_accuracy: 0.6274 - top5_accuracy: 0.7282
# Epoch 3: val_accuracy improved from 0.40121 to 0.42222, saving model to models/effv2b0_best.keras
#
# Epoch 3: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - accuracy: 0.4149 - loss: 2.0799 - top3_accuracy: 0.6351 - top5_accuracy: 0.7356 - val_accuracy: 0.4222 - val_loss: 2.1123 - val_top3_accuracy: 0.6291 - val_top5_accuracy: 0.7293 - learning_rate: 1.0000e-04
# Epoch 4/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4353 - loss: 2.0248 - top3_accuracy: 0.6473 - top5_accuracy: 0.7516
# Epoch 4: val_accuracy improved from 0.42222 to 0.43677, saving model to models/effv2b0_best.keras
#
# Epoch 4: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - accuracy: 0.4398 - loss: 1.9891 - top3_accuracy: 0.6529 - top5_accuracy: 0.7621 - val_accuracy: 0.4368 - val_loss: 2.0702 - val_top3_accuracy: 0.6396 - val_top5_accuracy: 0.7370 - learning_rate: 1.0000e-04
# Epoch 5/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4505 - loss: 1.9510 - top3_accuracy: 0.6703 - top5_accuracy: 0.7717
# Epoch 5: val_accuracy improved from 0.43677 to 0.44929, saving model to models/effv2b0_best.keras
#
# Epoch 5: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.4604 - loss: 1.9197 - top3_accuracy: 0.6745 - top5_accuracy: 0.7749 - val_accuracy: 0.4493 - val_loss: 2.0178 - val_top3_accuracy: 0.6477 - val_top5_accuracy: 0.7451 - learning_rate: 1.0000e-04
# Epoch 6/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4778 - loss: 1.8516 - top3_accuracy: 0.6909 - top5_accuracy: 0.7916
# Epoch 6: val_accuracy improved from 0.44929 to 0.46707, saving model to models/effv2b0_best.keras
#
# Epoch 6: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 24s 130ms/step - accuracy: 0.4849 - loss: 1.8204 - top3_accuracy: 0.7011 - top5_accuracy: 0.7966 - val_accuracy: 0.4671 - val_loss: 1.9749 - val_top3_accuracy: 0.6570 - val_top5_accuracy: 0.7556 - learning_rate: 1.0000e-04
# Epoch 7/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5029 - loss: 1.7650 - top3_accuracy: 0.7183 - top5_accuracy: 0.8059
# Epoch 7: val_accuracy improved from 0.46707 to 0.48808, saving model to models/effv2b0_best.keras
#
# Epoch 7: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - accuracy: 0.5080 - loss: 1.7306 - top3_accuracy: 0.7235 - top5_accuracy: 0.8150 - val_accuracy: 0.4881 - val_loss: 1.9122 - val_top3_accuracy: 0.6707 - val_top5_accuracy: 0.7604 - learning_rate: 1.0000e-04
# Epoch 8/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5193 - loss: 1.6993 - top3_accuracy: 0.7334 - top5_accuracy: 0.8172
# Epoch 8: val_accuracy improved from 0.48808 to 0.49414, saving model to models/effv2b0_best.keras
#
# Epoch 8: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 130ms/step - accuracy: 0.5298 - loss: 1.6565 - top3_accuracy: 0.7404 - top5_accuracy: 0.8274 - val_accuracy: 0.4941 - val_loss: 1.8760 - val_top3_accuracy: 0.6812 - val_top5_accuracy: 0.7709 - learning_rate: 1.0000e-04
# Epoch 9/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5491 - loss: 1.6177 - top3_accuracy: 0.7573 - top5_accuracy: 0.8384
# Epoch 9: val_accuracy improved from 0.49414 to 0.49939, saving model to models/effv2b0_best.keras
#
# Epoch 9: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 130ms/step - accuracy: 0.5564 - loss: 1.5846 - top3_accuracy: 0.7648 - top5_accuracy: 0.8438 - val_accuracy: 0.4994 - val_loss: 1.8432 - val_top3_accuracy: 0.6921 - val_top5_accuracy: 0.7713 - learning_rate: 1.0000e-04
# Epoch 10/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5624 - loss: 1.5357 - top3_accuracy: 0.7736 - top5_accuracy: 0.8527
# Epoch 10: val_accuracy improved from 0.49939 to 0.50909, saving model to models/effv2b0_best.keras
#
# Epoch 10: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.5694 - loss: 1.5010 - top3_accuracy: 0.7773 - top5_accuracy: 0.8585 - val_accuracy: 0.5091 - val_loss: 1.8191 - val_top3_accuracy: 0.6958 - val_top5_accuracy: 0.7838 - learning_rate: 1.0000e-04
# Epoch 11/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5858 - loss: 1.4729 - top3_accuracy: 0.7884 - top5_accuracy: 0.8612
# Epoch 11: val_accuracy improved from 0.50909 to 0.52929, saving model to models/effv2b0_best.keras
#
# Epoch 11: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - accuracy: 0.5959 - loss: 1.4312 - top3_accuracy: 0.7953 - top5_accuracy: 0.8690 - val_accuracy: 0.5293 - val_loss: 1.7743 - val_top3_accuracy: 0.7075 - val_top5_accuracy: 0.7875 - learning_rate: 1.0000e-04
# Epoch 12/12
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6058 - loss: 1.3942 - top3_accuracy: 0.8013 - top5_accuracy: 0.8699
# Epoch 12: val_accuracy improved from 0.52929 to 0.53172, saving model to models/effv2b0_best.keras
#
# Epoch 12: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.6135 - loss: 1.3673 - top3_accuracy: 0.8068 - top5_accuracy: 0.8754 - val_accuracy: 0.5317 - val_loss: 1.7572 - val_top3_accuracy: 0.7059 - val_top5_accuracy: 0.7927 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 12.

# %%
hist_ft_cont = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_FINETUNE*3,
    initial_epoch=EPOCHS_WARMUP+EPOCHS_FINETUNE,
    callbacks=tl_callbacks,
)
# Out:
# Epoch 25/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6236 - loss: 1.3293 - top3_accuracy: 0.8143 - top5_accuracy: 0.8837
# Epoch 25: val_accuracy improved from 0.53172 to 0.53980, saving model to models/effv2b0_best.keras
#
# Epoch 25: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 126ms/step - accuracy: 0.6300 - loss: 1.2919 - top3_accuracy: 0.8256 - top5_accuracy: 0.8935 - val_accuracy: 0.5398 - val_loss: 1.7128 - val_top3_accuracy: 0.7180 - val_top5_accuracy: 0.8044 - learning_rate: 1.0000e-04
# Epoch 26/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6472 - loss: 1.2522 - top3_accuracy: 0.8317 - top5_accuracy: 0.8993
# Epoch 26: val_accuracy improved from 0.53980 to 0.54384, saving model to models/effv2b0_best.keras
#
# Epoch 26: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 126ms/step - accuracy: 0.6529 - loss: 1.2227 - top3_accuracy: 0.8382 - top5_accuracy: 0.9037 - val_accuracy: 0.5438 - val_loss: 1.6981 - val_top3_accuracy: 0.7172 - val_top5_accuracy: 0.8040 - learning_rate: 1.0000e-04
# Epoch 27/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6457 - loss: 1.2180 - top3_accuracy: 0.8403 - top5_accuracy: 0.9062
# Epoch 27: val_accuracy did not improve from 0.54384
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 124ms/step - accuracy: 0.6540 - loss: 1.1976 - top3_accuracy: 0.8432 - top5_accuracy: 0.9087 - val_accuracy: 0.5438 - val_loss: 1.7045 - val_top3_accuracy: 0.7160 - val_top5_accuracy: 0.8008 - learning_rate: 1.0000e-04
# Epoch 28/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6591 - loss: 1.1730 - top3_accuracy: 0.8471 - top5_accuracy: 0.9143
# Epoch 28: val_accuracy improved from 0.54384 to 0.56121, saving model to models/effv2b0_best.keras
#
# Epoch 28: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 127ms/step - accuracy: 0.6763 - loss: 1.1235 - top3_accuracy: 0.8597 - top5_accuracy: 0.9195 - val_accuracy: 0.5612 - val_loss: 1.6501 - val_top3_accuracy: 0.7333 - val_top5_accuracy: 0.8077 - learning_rate: 1.0000e-04
# Epoch 29/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6675 - loss: 1.1337 - top3_accuracy: 0.8568 - top5_accuracy: 0.9165
# Epoch 29: val_accuracy improved from 0.56121 to 0.56525, saving model to models/effv2b0_best.keras
#
# Epoch 29: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 127ms/step - accuracy: 0.6839 - loss: 1.0968 - top3_accuracy: 0.8620 - top5_accuracy: 0.9199 - val_accuracy: 0.5653 - val_loss: 1.6490 - val_top3_accuracy: 0.7337 - val_top5_accuracy: 0.8117 - learning_rate: 1.0000e-04
# Epoch 30/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6949 - loss: 1.0586 - top3_accuracy: 0.8704 - top5_accuracy: 0.9305
# Epoch 30: val_accuracy improved from 0.56525 to 0.57131, saving model to models/effv2b0_best.keras
#
# Epoch 30: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.7037 - loss: 1.0289 - top3_accuracy: 0.8743 - top5_accuracy: 0.9322 - val_accuracy: 0.5713 - val_loss: 1.6380 - val_top3_accuracy: 0.7378 - val_top5_accuracy: 0.8133 - learning_rate: 1.0000e-04
# Epoch 31/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7138 - loss: 0.9906 - top3_accuracy: 0.8847 - top5_accuracy: 0.9311
# Epoch 31: val_accuracy improved from 0.57131 to 0.58343, saving model to models/effv2b0_best.keras
#
# Epoch 31: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 127ms/step - accuracy: 0.7225 - loss: 0.9610 - top3_accuracy: 0.8916 - top5_accuracy: 0.9375 - val_accuracy: 0.5834 - val_loss: 1.6134 - val_top3_accuracy: 0.7374 - val_top5_accuracy: 0.8133 - learning_rate: 1.0000e-04
# Epoch 32/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7206 - loss: 0.9614 - top3_accuracy: 0.8861 - top5_accuracy: 0.9343
# Epoch 32: val_accuracy improved from 0.58343 to 0.58384, saving model to models/effv2b0_best.keras
#
# Epoch 32: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - accuracy: 0.7285 - loss: 0.9390 - top3_accuracy: 0.8917 - top5_accuracy: 0.9377 - val_accuracy: 0.5838 - val_loss: 1.5977 - val_top3_accuracy: 0.7455 - val_top5_accuracy: 0.8178 - learning_rate: 1.0000e-04
# Epoch 33/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7275 - loss: 0.9131 - top3_accuracy: 0.8974 - top5_accuracy: 0.9462
# Epoch 33: val_accuracy improved from 0.58384 to 0.58465, saving model to models/effv2b0_best.keras
#
# Epoch 33: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.7388 - loss: 0.8906 - top3_accuracy: 0.9006 - top5_accuracy: 0.9468 - val_accuracy: 0.5846 - val_loss: 1.5840 - val_top3_accuracy: 0.7515 - val_top5_accuracy: 0.8267 - learning_rate: 1.0000e-04
# Epoch 34/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7546 - loss: 0.8589 - top3_accuracy: 0.9067 - top5_accuracy: 0.9468
# Epoch 34: val_accuracy improved from 0.58465 to 0.59758, saving model to models/effv2b0_best.keras
#
# Epoch 34: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 129ms/step - accuracy: 0.7624 - loss: 0.8328 - top3_accuracy: 0.9119 - top5_accuracy: 0.9509 - val_accuracy: 0.5976 - val_loss: 1.5728 - val_top3_accuracy: 0.7552 - val_top5_accuracy: 0.8238 - learning_rate: 1.0000e-04
# Epoch 35/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.7632 - loss: 0.8289 - top3_accuracy: 0.9091 - top5_accuracy: 0.9518
# Epoch 35: val_accuracy did not improve from 0.59758
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 126ms/step - accuracy: 0.7690 - loss: 0.8019 - top3_accuracy: 0.9164 - top5_accuracy: 0.9566 - val_accuracy: 0.5960 - val_loss: 1.5568 - val_top3_accuracy: 0.7560 - val_top5_accuracy: 0.8246 - learning_rate: 1.0000e-04
# Epoch 36/36
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7765 - loss: 0.7841 - top3_accuracy: 0.9185 - top5_accuracy: 0.9551
# Epoch 36: val_accuracy improved from 0.59758 to 0.60000, saving model to models/effv2b0_best.keras
#
# Epoch 36: finished saving model to models/effv2b0_best.keras
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 23s 128ms/step - accuracy: 0.7769 - loss: 0.7652 - top3_accuracy: 0.9225 - top5_accuracy: 0.9588 - val_accuracy: 0.6000 - val_loss: 1.5489 - val_top3_accuracy: 0.7600 - val_top5_accuracy: 0.8295 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 36.

# %% [markdown]
# ## 7. Графики обучения
#
# Графики позволяют быстро увидеть:
#
# - есть ли переобучение;
# - достигла ли модель плато;
# - помог ли fine-tuning после warmup;
# - не слишком ли большой learning rate.

# %%
def merge_histories(*histories):
    merged = {}
    for history in histories:
        if history is None:
            continue
        for key, values in history.history.items():
            merged.setdefault(key, []).extend(values)
    return merged

def plot_training_curves(history_dict, title="Обучение модели"):
    metrics = [
        ("accuracy", "val_accuracy", "Accuracy"),
        ("top3_accuracy", "val_top3_accuracy", "Top-3 accuracy"),
        ("top5_accuracy", "val_top5_accuracy", "Top-5 accuracy"),
        ("loss", "val_loss", "Loss"),
    ]

    for train_key, val_key, metric_name in metrics:
        if train_key not in history_dict or val_key not in history_dict:
            continue

        plt.figure(figsize=(8, 5))
        plt.plot(history_dict[train_key], label="train")
        plt.plot(history_dict[val_key], label="val")
        plt.title(f"{title}: {metric_name}")
        plt.xlabel("Эпоха")
        plt.ylabel(metric_name)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()

history_all = merge_histories(hist_warmup, hist_ft, hist_ft_cont)
plot_training_curves(history_all, title="EfficientNetV2B0")

# %% [markdown]
# ## 8. Оценка на test и подробные метрики
#
# Обычная accuracy не всегда достаточно информативна. Для 33 классов полезны:
#
# - `top-3 accuracy`: правильная марка попала в 3 наиболее вероятных варианта;
# - `top-5 accuracy`: правильная марка попала в 5 вариантов;
# - precision/recall/F1 по каждому классу;
# - confusion matrix.

# %%
best_tl_path = "models/effv2b0_best.keras"

if os.path.exists(best_tl_path):
    model_tl.load_weights(best_tl_path)
    print("Загружены лучшие веса:", best_tl_path)
else:
    print("Лучший checkpoint не найден, используются текущие веса модели.")

test_metrics = model_tl.evaluate(test_ds, verbose=0)
print("Метрики EfficientNetV2B0 на test:")
for name, value in zip(model_tl.metrics_names, test_metrics):
    print(f"{name}: {value:.4f}")

y_true = df_test["label_idx"].values
y_pred_proba = model_tl.predict(test_ds, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)

print("\nПроверка top-k через sklearn:")
print("Top-3 accuracy:", top_k_accuracy_score(y_true, y_pred_proba, k=3, labels=np.arange(num_classes)))
print("Top-5 accuracy:", top_k_accuracy_score(y_true, y_pred_proba, k=5, labels=np.arange(num_classes)))

report = classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0,
    output_dict=True,
)
report_df = pd.DataFrame(report).T
display(report_df)
# Out:
# Загружены лучшие веса: models/effv2b0_best.keras
# Метрики EfficientNetV2B0 на test:
# loss: 1.5732
# compile_metrics: 0.6012
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step
#
# Проверка top-k через sklearn:
# Top-3 accuracy: 0.7470707070707071
# Top-5 accuracy: 0.8177777777777778
#                precision    recall  f1-score      support
# Acura           0.666667  0.453333  0.539683    75.000000
# Aston Martin    0.698925  0.866667  0.773810    75.000000
# Audi            0.628205  0.653333  0.640523    75.000000
# BMW             0.603448  0.466667  0.526316    75.000000
# Bentley         0.696203  0.733333  0.714286    75.000000
# Buick           0.564706  0.640000  0.600000    75.000000
# Cadillac        0.592593  0.640000  0.615385    75.000000
# Chevrolet       0.660000  0.440000  0.528000    75.000000
# Chrysler        0.794872  0.826667  0.810458    75.000000
# Dodge           0.605634  0.573333  0.589041    75.000000
# FIAT            0.845070  0.800000  0.821918    75.000000
# Ford            0.394737  0.200000  0.265487    75.000000
# GMC             0.610526  0.773333  0.682353    75.000000
# Honda           0.466667  0.186667  0.266667    75.000000
# Hyundai         0.555556  0.400000  0.465116    75.000000
# INFINITI        0.643836  0.626667  0.635135    75.000000
# Jaguar          0.451220  0.493333  0.471338    75.000000
# Jeep            0.776316  0.786667  0.781457    75.000000
# Kia             0.491803  0.400000  0.441176    75.000000
# Land Rover      0.693182  0.813333  0.748466    75.000000
# Lexus           0.478261  0.586667  0.526946    75.000000
# Lincoln         0.635135  0.626667  0.630872    75.000000
# MINI            0.772727  0.906667  0.834356    75.000000
# Mazda           0.602941  0.546667  0.573427    75.000000
# Mercedes-Benz   0.512500  0.546667  0.529032    75.000000
# Mitsubishi      0.495652  0.760000  0.600000    75.000000
# Nissan          0.402985  0.360000  0.380282    75.000000
# Porsche         0.631579  0.640000  0.635762    75.000000
# Ram             0.811765  0.920000  0.862500    75.000000
# Subaru          0.552632  0.560000  0.556291    75.000000
# Toyota          0.437500  0.466667  0.451613    75.000000
# Volkswagen      0.473118  0.586667  0.523810    75.000000
# Volvo           0.471910  0.560000  0.512195    75.000000
# accuracy        0.601212  0.601212  0.601212     0.601212
# macro avg       0.597541  0.601212  0.591930  2475.000000
# weighted avg    0.597541  0.601212  0.591930  2475.000000

# %%
cm = confusion_matrix(y_true, y_pred, labels=np.arange(num_classes))

plt.figure(figsize=(16, 14))
sns.heatmap(
    cm,
    cmap="Blues",
    xticklabels=classes,
    yticklabels=classes,
    square=False,
    cbar=True,
)
plt.title("Confusion matrix на test")
plt.xlabel("Предсказанный класс")
plt.ylabel("Истинный класс")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Нормированная матрица показывает доли ошибок внутри каждого истинного класса.
cm_norm = cm.astype("float") / np.maximum(cm.sum(axis=1, keepdims=True), 1)

plt.figure(figsize=(16, 14))
sns.heatmap(
    cm_norm,
    cmap="Blues",
    xticklabels=classes,
    yticklabels=classes,
    square=False,
    cbar=True,
)
plt.title("Нормированная confusion matrix на test")
plt.xlabel("Предсказанный класс")
plt.ylabel("Истинный класс")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Таблица самых частых пар ошибок.
error_pairs = []
for true_idx in range(num_classes):
    for pred_idx in range(num_classes):
        if true_idx != pred_idx and cm[true_idx, pred_idx] > 0:
            error_pairs.append({
                "true_class": idx2class[true_idx],
                "pred_class": idx2class[pred_idx],
                "count": int(cm[true_idx, pred_idx]),
                "share_within_true_class": float(cm_norm[true_idx, pred_idx]),
            })

error_pairs_df = pd.DataFrame(error_pairs).sort_values(
    ["count", "share_within_true_class"],
    ascending=False,
)
display(error_pairs_df.head(30))
# Out:
#     true_class     pred_class  count  share_within_true_class
# 109  Chevrolet            GMC     11                 0.146667
# 170       Ford            GMC      8                 0.106667
# 220      Honda         Toyota      7                 0.093333
# 248   INFINITI          Lexus      7                 0.093333
# 300        Kia     Mitsubishi      7                 0.093333
# 39        Audi     Volkswagen      6                 0.080000
# 167       Ford      Chevrolet      6                 0.080000
# 186       Ford          Volvo      6                 0.080000
# 221      Honda     Volkswagen      6                 0.080000
# 224    Hyundai          Buick      6                 0.080000
# 233    Hyundai          Mazda      6                 0.080000
# 235    Hyundai     Mitsubishi      6                 0.080000
# 2        Acura       Cadillac      5                 0.066667
# 13       Acura          Mazda      5                 0.066667
# 14       Acura  Mercedes-Benz      5                 0.066667
# 40        Audi          Volvo      5                 0.066667
# 79       Buick          Lexus      5                 0.066667
# 216      Honda     Mitsubishi      5                 0.066667
# 265     Jaguar          Lexus      5                 0.066667
# 271     Jaguar     Volkswagen      5                 0.066667
# 366      Mazda          Dodge      5                 0.066667
# 468     Subaru         Jaguar      5                 0.066667
# 38        Audi  Mercedes-Benz      4                 0.053333
# 43         BMW           Audi      4                 0.053333
# 50         BMW       INFINITI      4                 0.053333
# 61         BMW          Volvo      4                 0.053333
# 69     Bentley     Volkswagen      4                 0.053333
# 147      Dodge     Mitsubishi      4                 0.053333
# 156       FIAT           MINI      4                 0.053333
# 168       Ford          Dodge      4                 0.053333

# %% [markdown]
# ## 9. Анализ ошибочных предсказаний
#
# - похожие модели
# - фото салона, дисков и т.п. сбивают нейронку

# %%
def show_misclassified_examples(df, y_true, y_pred, y_pred_proba, n=24):
    wrong_idx = np.where(y_true != y_pred)[0]
    if len(wrong_idx) == 0:
        print("Ошибок не найдено.")
        return

    # Уверенность модели в ошибочном предсказании.
    wrong_conf = y_pred_proba[wrong_idx, y_pred[wrong_idx]]
    order = wrong_idx[np.argsort(-wrong_conf)]
    selected = order[:n]

    cols = 4
    rows = int(np.ceil(len(selected) / cols))
    plt.figure(figsize=(4 * cols, 4 * rows))

    for i, idx in enumerate(selected, start=1):
        img = decode_image(df.iloc[idx]["path"]).numpy()

        true_name = idx2class[int(y_true[idx])]
        pred_name = idx2class[int(y_pred[idx])]
        conf = float(y_pred_proba[idx, y_pred[idx]])

        top5 = np.argsort(-y_pred_proba[idx])[:5]
        top5_text = ", ".join([f"{idx2class[int(j)]}: {y_pred_proba[idx, j]:.2f}" for j in top5])

        plt.subplot(rows, cols, i)
        plt.imshow(img)
        plt.axis("off")
        plt.title(f"true: {true_name}\npred: {pred_name} ({conf:.2f})", fontsize=9)
        print(f"{idx}. true={true_name}, pred={pred_name}, top5=[{top5_text}], path={df.iloc[idx]['path']}")

    plt.tight_layout()
    plt.show()

show_misclassified_examples(df_test, y_true, y_pred, y_pred_proba, n=24)
# Out:
# 551. true=Chevrolet, pred=Land Rover, top5=[Land Rover: 0.98, Lincoln: 0.00, GMC: 0.00, Ford: 0.00, Chevrolet: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Blazer_1998_21_15_190_43_6_67_64_nan_16_RWD_4_2_SUV_fYG.jpg
# 617. true=Chrysler, pred=Cadillac, top5=[Cadillac: 0.97, Chevrolet: 0.01, Chrysler: 0.01, GMC: 0.00, Jaguar: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chrysler/Chrysler_300_2017_41_19_290_36_6_75_59_198_18_AWD_5_4_4dr_wOl.jpg
# 876. true=Ford, pred=Ram, top5=[Ram: 0.96, GMC: 0.02, Ford: 0.01, Toyota: 0.00, Land Rover: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_F-150_2016_26_17_280_35_6_79_75_209_18_RWD_3_2_Pickup_oPD.jpg
# 559. true=Chevrolet, pred=GMC, top5=[GMC: 0.96, Ram: 0.02, Chevrolet: 0.01, Land Rover: 0.00, Cadillac: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Suburban_2017_49_18_350_53_8_80_74_nan_16_RWD_8_4_SUV_mkp.jpg
# 833. true=Ford, pred=FIAT, top5=[FIAT: 0.96, Jaguar: 0.01, Subaru: 0.01, Volkswagen: 0.00, Porsche: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Fusion_2019_27_18_240_20_4_75_58_191_20_AWD_5_4_4dr_JqG.jpg
# 1210. true=Jaguar, pred=Aston Martin, top5=[Aston Martin: 0.95, Lincoln: 0.04, Mercedes-Benz: 0.01, Bentley: 0.00, Mazda: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Jaguar/Jaguar_XJ_2011_72_19_380_50_8_74_57_201_16_RWD_5_4_4dr_kHd.jpg
# 2213. true=Subaru, pred=Volvo, top5=[Volvo: 0.94, INFINITI: 0.03, BMW: 0.01, Lincoln: 0.00, Mercedes-Benz: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Subaru/Subaru_Legacy_2016_21_17_170_25_4_72_59_188_26_AWD_5_4_4dr_jpz.jpg
# 1077. true=Hyundai, pred=Mitsubishi, top5=[Mitsubishi: 0.94, Lexus: 0.02, INFINITI: 0.01, Honda: 0.01, Kia: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Hyundai/Hyundai_Kona Electric_2020_41_17_200_nan_nan_70_61_164_nan_FWD_5_4_SUV_NQT.jpg
# 294. true=BMW, pred=Bentley, top5=[Bentley: 0.94, Mercedes-Benz: 0.02, BMW: 0.01, Porsche: 0.01, Lincoln: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/BMW/BMW_7-Series_2019_91_18_320_20_4_74_58_206_nan_AWD_5_4_4dr_ZfR.jpg
# 869. true=Ford, pred=Audi, top5=[Audi: 0.94, Hyundai: 0.04, Toyota: 0.01, Chevrolet: 0.00, Volkswagen: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Mustang_2011_34_18_410_50_8_73_56_188_nan_RWD_4_2_Convertible_UDC.jpg
# 826. true=Ford, pred=Chevrolet, top5=[Chevrolet: 0.93, GMC: 0.04, Ram: 0.01, Toyota: 0.00, Dodge: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_F-150_2017_51_18_380_50_8_79_75_231_15_RWD_5_4_Pickup_uVQ.jpg
# 854. true=Ford, pred=GMC, top5=[GMC: 0.93, Chevrolet: 0.02, MINI: 0.02, Toyota: 0.01, Subaru: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2012_47_18_380_62_8_79_77_nan_nan_RWD_5_4_Pickup_our.jpg
# 1582. true=Lincoln, pred=Aston Martin, top5=[Aston Martin: 0.93, Jaguar: 0.01, INFINITI: 0.01, Mercedes-Benz: 0.01, Lexus: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Lincoln/Lincoln_MKZ_2016_37_18_240_20_4_73_58_194_22_AWD_5_4_4dr_Vdt.jpg
# 2216. true=Subaru, pred=Volvo, top5=[Volvo: 0.92, Subaru: 0.06, Buick: 0.00, Jaguar: 0.00, BMW: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Subaru/Subaru_Legacy_2014_21_16_170_25_4_71_59_187_24_AWD_5_4_4dr_ckl.jpg
# 1421. true=Kia, pred=Mitsubishi, top5=[Mitsubishi: 0.92, Kia: 0.03, Mazda: 0.01, Lincoln: 0.01, Dodge: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Kia/Kia_Sportage_2015_25_18_180_24_4_73_64_174_21_FWD_5_4_SUV_qse.jpg
# 886. true=Ford, pred=Chevrolet, top5=[Chevrolet: 0.92, GMC: 0.04, Ford: 0.03, Toyota: 0.00, Subaru: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2019_55_18_380_62_8_80_78_250_nan_RWD_5_4_Pickup_FAd.jpg
# 1227. true=Jaguar, pred=Lincoln, top5=[Lincoln: 0.91, Bentley: 0.05, Mercedes-Benz: 0.02, BMW: 0.01, Buick: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Jaguar/Jaguar_I-Pace_2020_80_20_390_nan_nan_74_61_184_nan_AWD_5_4_SUV_drg.jpg
# 963. true=GMC, pred=FIAT, top5=[FIAT: 0.90, MINI: 0.05, Chevrolet: 0.01, GMC: 0.01, Land Rover: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/GMC/GMC_Yukon_2014_58_20_400_62_8_79_76_nan_14_RWD_7_4_SUV_HMp.jpg
# 1040. true=Honda, pred=Lincoln, top5=[Lincoln: 0.90, Acura: 0.02, Honda: 0.02, Volvo: 0.02, Audi: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Honda/Honda_Odyssey_2016_32_17_240_35_6_79_68_202_19_FWD_8_4_Van_tdT.jpg
# 435. true=Buick, pred=Honda, top5=[Honda: 0.90, Cadillac: 0.02, Buick: 0.02, Chevrolet: 0.02, Nissan: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Buick/Buick_Lacrosse_2016_33_18_300_36_6_73_59_196_18_FWD_5_4_4dr_FNk.jpg
# 875. true=Ford, pred=Land Rover, top5=[Land Rover: 0.90, Lincoln: 0.05, MINI: 0.02, Ford: 0.01, Dodge: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Flex_2017_40_19_280_35_6_75_68_201_nan_AWD_7_4_SUV_APp.jpg
# 2417. true=Volvo, pred=Jeep, top5=[Jeep: 0.90, BMW: 0.03, Audi: 0.02, Volvo: 0.01, Jaguar: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Volvo/Volvo_XC90_2016_53_20_250_20_4_79_69_194_22_AWD_5_4_SUV_rKC.jpg
# 2005. true=Nissan, pred=Lincoln, top5=[Lincoln: 0.90, Subaru: 0.02, Volkswagen: 0.01, Jaguar: 0.01, Chrysler: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Nissan/Nissan_Altima_2011_23_17_170_25_4_70_55_180_23_FWD_5_2_2dr_NGq.jpg
# 572. true=Chevrolet, pred=GMC, top5=[GMC: 0.90, Chevrolet: 0.08, Toyota: 0.01, Nissan: 0.00, Cadillac: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Silverado 2500HD_2016_53_20_360_60_8_80_78_nan_nan_RWD_5_4_Pickup_FAI.jpg

# %% [markdown]
# Общий вывод по работе: работает распознавание хороших ракурсов, но с учетом того что многие машины отличаются друг от друга по сути только шильдиком, тут тоже есть ошибки.
#
# Отвратительную роль играют выбросы - фото салона, дисков, брошюрок, 'машина на фоне самолета', 'три машины где-то далеко' и т.п. - они не только идут методом случайного угадывания, но еще и портят общее обучение модели.
#
# К сожалению выбросить их просто так не получиться
# - они все-таки часть датасета и составляют значительную его часть
# - есть редкие модели - винтажные хонды, астон мартины и т.д. у них тоже всего несколько фоток в датасете и при автоматической чистке мы тоже выкинем
