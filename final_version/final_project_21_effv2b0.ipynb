# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf

print("Версия TensorFlow:", tf.__version__)
print("Доступные GPU:", tf.config.list_physical_devices('GPU'))
tf.config.set_visible_devices(tf.config.list_physical_devices('GPU')[0], 'GPU')
# Out:
# Версия TensorFlow: 2.21.0
# Доступные GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2B0, preprocess_input
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint,
    CSVLogger,
)

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score, accuracy_score

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE

DATA_DIR = Path("/home/sm/Desktop/ml/CarBrandClassificationDataset")

EPOCHS_WARMUP = 12
EPOCHS_FINETUNE = 12

AUTO = tf.data.AUTOTUNE

MODEL_DIR = Path("models")
MODEL_DIR.mkdir(exist_ok=True)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# ## 1. Загрузка структуры датасета
#
# Ожидается структура:
#
# ```text
# CarBrandClassificationDataset/
# ├── train/
# │   ├── class_1/
# │   └── ...
# ├── val/
# │   ├── class_1/
# │   └── ...
# └── test/
#     ├── class_1/
#     └── ...
# ```
#
# В таблицы ниже собираются пути к изображениям и строковые метки классов.

# %%
train_base = DATA_DIR / "train"
val_base = DATA_DIR / "val"
test_base = DATA_DIR / "test"

IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

def build_split_df(split_dir: Path) -> pd.DataFrame:
    """Собирает таблицу path/label для одного split'а."""
    if not split_dir.exists():
        raise FileNotFoundError(f"Папка split'а не найдена: {split_dir}")

    rows = []
    class_dirs = sorted([d for d in split_dir.iterdir() if d.is_dir()])
    for cls_dir in class_dirs:
        cls = cls_dir.name
        for f in cls_dir.rglob("*"):
            if f.is_file() and f.suffix.lower() in IMAGE_EXTENSIONS:
                rows.append((str(f), cls))
    return pd.DataFrame(rows, columns=["path", "label"])

df_train = build_split_df(train_base)
df_val = build_split_df(val_base)
df_test = build_split_df(test_base)

print("Количество изображений:")
print("Train:", len(df_train), "| классов:", df_train["label"].nunique())
print("Val  :", len(df_val), "| классов:", df_val["label"].nunique())
print("Test :", len(df_test), "| классов:", df_test["label"].nunique())

display(pd.concat({
    "train": df_train["label"].value_counts().sort_index(),
    "val": df_val["label"].value_counts().sort_index(),
    "test": df_test["label"].value_counts().sort_index(),
}, axis=1).fillna(0).astype(int).head())
# Out:
# Количество изображений:
# Train: 11517 | классов: 33
# Val  : 2475 | классов: 33
# Test : 2475 | классов: 33
#               train  val  test
# label
# Acura           349   75    75
# Aston Martin    349   75    75
# Audi            349   75    75
# BMW             349   75    75
# Bentley         349   75    75

# %%
# Единое отображение классов в индексы.
classes = sorted(df_train["label"].unique().tolist())
class2idx = {c: i for i, c in enumerate(classes)}
idx2class = {i: c for c, i in class2idx.items()}
num_classes = len(classes)

for name, df in [("val", df_val), ("test", df_test)]:
    missing = set(df["label"].unique()) - set(classes)
    if missing:
        raise ValueError(f"В {name} есть классы, которых нет в train: {sorted(missing)}")

df_train["label_idx"] = df_train["label"].map(class2idx)
df_val["label_idx"] = df_val["label"].map(class2idx)
df_test["label_idx"] = df_test["label"].map(class2idx)

print("Число классов:", num_classes)
print("Пример отображения:", list(class2idx.items())[:10])
df_train.head()
# Out:
# Число классов: 33
# Пример отображения: [('Acura', 0), ('Aston Martin', 1), ('Audi', 2), ('BMW', 3), ('Bentley', 4), ('Buick', 5), ('Cadillac', 6), ('Chevrolet', 7), ('Chrysler', 8), ('Dodge', 9)]
#                                                 path  label  label_idx
# 0  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 1  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 2  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 3  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0
# 4  /home/sm/Desktop/ml/CarBrandClassificationData...  Acura          0

# %% [markdown]
# ## 2. Распределение изображений по классам
#
# равномерное распределение по всем классам

# %%
def plot_class_distribution(df: pd.DataFrame, title: str) -> None:
    counts = df["label"].value_counts().sort_values(ascending=False)
    plt.figure(figsize=(14, 5))
    sns.barplot(x=counts.index, y=counts.values)
    plt.title(title)
    plt.xlabel("Класс")
    plt.ylabel("Количество изображений")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

plot_class_distribution(df_train, "Распределение классов в train")
plot_class_distribution(df_val, "Распределение классов в val")
plot_class_distribution(df_test, "Распределение классов в test")

class_counts = df_train["label_idx"].value_counts().sort_index()
imbalance_ratio = class_counts.max() / max(class_counts.min(), 1)
print(f"Коэффициент дисбаланса train max/min: {imbalance_ratio:.2f}")
# Out:
# Коэффициент дисбаланса train max/min: 1.00

# %% [markdown]
# ## 3. `tf.data`-пайплайн и аугментация
#
# Используется resize_with_pad, т.к. для авто критичны пропорции (resize) и нельзя обрезать (crop) - мы рискуем потерять важную часть изображения
#
# Для EfficientNet используется совместимый с ImageNet-предобучением `preprocess_input`(взял из примера, в доках прочитал, что это уже фунция заглушка, функционал встроен в модель).

# %%
def decode_image(path):
    """Читает изображение, приводит к RGB, float32 и нужному размеру."""
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize_with_pad(img, IMG_SIZE[0], IMG_SIZE[1])
    return img

augmenter = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.08, 0.08),
    layers.RandomContrast(0.15),
], name="augmenter")

def make_ds(paths, labels, augment=False, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    if shuffle:
        ds = ds.shuffle(min(len(paths), 4096), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(lambda x, y: (decode_image(x), y), num_parallel_calls=AUTO)
    ds = ds.cache()

    if augment:
        ds = ds.map(lambda x, y: (augmenter(x, training=True),y), num_parallel_calls=AUTO)

    ds = ds.map(lambda x, y: (preprocess_input(x * 255.0),y),num_parallel_calls=AUTO)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(AUTO)

    return ds

train_ds = make_ds(
    df_train["path"].tolist(),
    df_train["label_idx"].tolist(),
    augment=True,
    shuffle=True,
)

val_ds = make_ds(
    df_val["path"].tolist(),
    df_val["label_idx"].tolist(),
)

test_ds = make_ds(
    df_test["path"].tolist(),
    df_test["label_idx"].tolist(),
)

print(train_ds)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## 4. Transfer learning: EfficientNetB0V2
#
# используем предобученную на других данных модель для решения нашей задачи
#
# сначала подбор гиперпараметров, нормальный gridsearch строить не стал, потому что этот полчаса отрабатывал полный перебор с нормальным количеством вариаций может и дал бы небольшой прирост, но за сутки ноут бы сдох

# %%
search_space = [

    {
        "dropout": 0.25,
        "dense_units": 128,
        "lr": 3e-4,
    },

    {
        "dropout": 0.35,
        "dense_units": 256,
        "lr": 3e-4,
    },

    {
        "dropout": 0.40,
        "dense_units": 256,
        "lr": 1e-4,
    },

    {
        "dropout": 0.35,
        "dense_units": 512,
        "lr": 3e-4,
    },

    {
        "dropout": 0.4,
        "dense_units": 512,
        "lr": 3e-4,
    },
]

def build_model(dropout,dense_units,lr):
    base_model = EfficientNetV2B0(
        include_top=False,
        weights="imagenet",
        input_shape=IMG_SIZE + (3,),
    )

    base_model.trainable = False
    inputs = layers.Input(shape=IMG_SIZE + (3,))
    x = base_model(inputs,training=False)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units,activation="relu",)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout * 0.75)(x)

    outputs = layers.Dense(
        num_classes,
        activation="softmax",
        dtype="float32",
    )(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=[
            "accuracy",
            tf.keras.metrics.SparseTopKCategoricalAccuracy(
                k=5,
                name="top5_acc",
            ),
        ],
    )

    return model

# %%
search_results = []

best_model = None
best_val_acc = 0.0

for i, config in enumerate(search_space):

    print("=" * 60)
    print(f"CONFIG {i+1}/{len(search_space)}")
    print(config)

    model_hp = build_model(
        dropout=config["dropout"],
        dense_units=config["dense_units"],
        lr=config["lr"],
    )

    history_hp = model_hp.fit(
        train_ds,
        validation_data=val_ds,
        epochs=5,
        verbose=1,
    )

    best_epoch_acc = max(
        history_hp.history["val_accuracy"]
    )

    search_results.append({
        **config,
        "val_accuracy": best_epoch_acc,
    })

    print(f"Best val_accuracy: {best_epoch_acc:.4f}")

    if best_epoch_acc > best_val_acc:
        best_val_acc = best_epoch_acc
        best_model = model_hp

print("\nBEST VAL ACC:", best_val_acc)
# Out:
# ============================================================
# CONFIG 1/5
# {'dropout': 0.25, 'dense_units': 128, 'lr': 0.0003}
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 72s 136ms/step - accuracy: 0.0710 - loss: 3.8098 - top5_acc: 0.2519 - val_accuracy: 0.1240 - val_loss: 3.2274 - val_top5_acc: 0.3588
# Epoch 2/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1178 - loss: 3.3541 - top5_acc: 0.3550 - val_accuracy: 0.1543 - val_loss: 3.0768 - val_top5_acc: 0.4376
# Epoch 3/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1526 - loss: 3.1791 - top5_acc: 0.4091 - val_accuracy: 0.1826 - val_loss: 2.9540 - val_top5_acc: 0.4857
# Epoch 4/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1758 - loss: 3.0457 - top5_acc: 0.4545 - val_accuracy: 0.2020 - val_loss: 2.8645 - val_top5_acc: 0.5143
# Epoch 5/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1981 - loss: 2.9346 - top5_acc: 0.4982 - val_accuracy: 0.2246 - val_loss: 2.7997 - val_top5_acc: 0.5422
# Best val_accuracy: 0.2246
# ============================================================
# CONFIG 2/5
# {'dropout': 0.35, 'dense_units': 256, 'lr': 0.0003}
# Epoch 1/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 49s 97ms/step - accuracy: 0.0770 - loss: 3.9248 - top5_acc: 0.2657 - val_accuracy: 0.1265 - val_loss: 3.1734 - val_top5_acc: 0.3980
# Epoch 2/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1248 - loss: 3.4186 - top5_acc: 0.3636 - val_accuracy: 0.1741 - val_loss: 2.9812 - val_top5_acc: 0.4857
# Epoch 3/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1574 - loss: 3.1723 - top5_acc: 0.4313 - val_accuracy: 0.1891 - val_loss: 2.8692 - val_top5_acc: 0.5325
# Epoch 4/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1816 - loss: 3.0533 - top5_acc: 0.4625 - val_accuracy: 0.2291 - val_loss: 2.7679 - val_top5_acc: 0.5539
# Epoch 5/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.2001 - loss: 2.9389 - top5_acc: 0.4961 - val_accuracy: 0.2432 - val_loss: 2.7200 - val_top5_acc: 0.5657
# Best val_accuracy: 0.2432
# ============================================================
# CONFIG 3/5
# {'dropout': 0.4, 'dense_units': 256, 'lr': 0.0001}
# Epoch 1/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 46s 92ms/step - accuracy: 0.0453 - loss: 4.3221 - top5_acc: 0.1959 - val_accuracy: 0.0941 - val_loss: 3.4143 - val_top5_acc: 0.3006
# Epoch 2/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.0728 - loss: 3.9148 - top5_acc: 0.2664 - val_accuracy: 0.1317 - val_loss: 3.2414 - val_top5_acc: 0.3689
# Epoch 3/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.0913 - loss: 3.7143 - top5_acc: 0.3110 - val_accuracy: 0.1519 - val_loss: 3.1302 - val_top5_acc: 0.4121
# Epoch 4/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.1032 - loss: 3.5780 - top5_acc: 0.3308 - val_accuracy: 0.1729 - val_loss: 3.0487 - val_top5_acc: 0.4392
# Epoch 5/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.1163 - loss: 3.4674 - top5_acc: 0.3613 - val_accuracy: 0.1834 - val_loss: 2.9879 - val_top5_acc: 0.4626
# Best val_accuracy: 0.1834
# ============================================================
# CONFIG 4/5
# {'dropout': 0.35, 'dense_units': 512, 'lr': 0.0003}
# Epoch 1/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 49s 97ms/step - accuracy: 0.0995 - loss: 3.8878 - top5_acc: 0.2951 - val_accuracy: 0.1366 - val_loss: 3.1316 - val_top5_acc: 0.4166
# Epoch 2/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1505 - loss: 3.3431 - top5_acc: 0.4069 - val_accuracy: 0.1992 - val_loss: 2.9123 - val_top5_acc: 0.4974
# Epoch 3/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.1875 - loss: 3.0948 - top5_acc: 0.4711 - val_accuracy: 0.2097 - val_loss: 2.8389 - val_top5_acc: 0.5410
# Epoch 4/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.2166 - loss: 2.9407 - top5_acc: 0.5114 - val_accuracy: 0.2440 - val_loss: 2.7282 - val_top5_acc: 0.5632
# Epoch 5/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.2337 - loss: 2.8250 - top5_acc: 0.5401 - val_accuracy: 0.2695 - val_loss: 2.6454 - val_top5_acc: 0.5842
# Best val_accuracy: 0.2695
# ============================================================
# CONFIG 5/5
# {'dropout': 0.4, 'dense_units': 512, 'lr': 0.0003}
# Epoch 1/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 46s 93ms/step - accuracy: 0.0873 - loss: 3.9475 - top5_acc: 0.2843 - val_accuracy: 0.1418 - val_loss: 3.1175 - val_top5_acc: 0.4287
# Epoch 2/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.1360 - loss: 3.4214 - top5_acc: 0.3966 - val_accuracy: 0.1838 - val_loss: 2.9291 - val_top5_acc: 0.5002
# Epoch 3/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.1760 - loss: 3.1821 - top5_acc: 0.4434 - val_accuracy: 0.2125 - val_loss: 2.8403 - val_top5_acc: 0.5426
# Epoch 4/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1998 - loss: 3.0228 - top5_acc: 0.4887 - val_accuracy: 0.2448 - val_loss: 2.7314 - val_top5_acc: 0.5632
# Epoch 5/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.2191 - loss: 2.9122 - top5_acc: 0.5158 - val_accuracy: 0.2606 - val_loss: 2.6637 - val_top5_acc: 0.5952
# Best val_accuracy: 0.2606
#
# BEST VAL ACC: 0.2694949507713318

# %%
results_hp_df = pd.DataFrame(
    search_results
)

results_hp_df = results_hp_df.sort_values(
    by="val_accuracy",
    ascending=False,
)

results_hp_df
# Out:
#    dropout  dense_units      lr  val_accuracy
# 3     0.35          512  0.0003      0.269495
# 4     0.40          512  0.0003      0.260606
# 1     0.35          256  0.0003      0.243232
# 0     0.25          128  0.0003      0.224646
# 2     0.40          256  0.0001      0.183434

# %%
best_config = results_hp_df.iloc[0]
best_config
# Out:
# dropout           0.350000
# dense_units     512.000000
# lr                0.000300
# val_accuracy      0.269495
# Name: 3, dtype: float64

# %% [markdown]
# забил параметры руками, чтобы спокойно перезапускать

# %%
def build_efficientnet(num_classes: int, img_size=IMG_SIZE, dropout=0.35, dense_units=512) -> tuple[tf.keras.Model, tf.keras.Model]:
    base = EfficientNetV2B0(
        include_top=False,
        weights="imagenet",
        input_shape=(*img_size, 3),
    )
    base.trainable = False

    inputs = layers.Input(shape=(*img_size, 3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Dense(dense_units, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout * 0.75)(x)

    logits = layers.Dense(num_classes)(x)
    outputs = layers.Activation("softmax", dtype="float32")(logits)

    model = models.Model(inputs, outputs, name="efficientnetb0_car_brand")
    return model, base

def compile_model(model: tf.keras.Model, lr: float) -> None:
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="sparse_categorical_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top3_accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_accuracy"),
        ],
    )

model_tl, base = build_efficientnet(num_classes)
compile_model(model_tl, lr=3e-4)
model_tl.summary()
# Out:
# Model: "efficientnetb0_car_brand"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 7, 7, 1280)     │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 33)             │        16,929 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 33)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,599,281 (25.17 MB)
#  Trainable params: 676,385 (2.58 MB)
#  Non-trainable params: 5,922,896 (22.59 MB)

# %% [markdown]
# обучение классификатора на фиксированных признаках
#
# так как мы используем предобученную модель, то я замораживаю исходные слои, добавил свои и обучаю пока только их

# %%
tl_callbacks = [
    ModelCheckpoint(
        "models/effv2b0_best.keras",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=1,
    ),
    EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=6,
        restore_best_weights=True,
        verbose=1,
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-7,
        verbose=1,
    ),
    CSVLogger("models/effv2b0_training_log.csv", append=False),
]

print("Этап 1: обучение classifier head при замороженном backbone.")
hist_warmup = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_WARMUP,
    callbacks=tl_callbacks,
)
# Out:
# Этап 1: обучение classifier head при замороженном backbone.
# Epoch 1/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0809 - loss: 4.0520 - top3_accuracy: 0.1844 - top5_accuracy: 0.2652
# Epoch 1: val_accuracy improved from None to 0.14141, saving model to models/effv2b0_best.keras
#
# Epoch 1: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 47s 94ms/step - accuracy: 0.0984 - loss: 3.8581 - top3_accuracy: 0.2171 - top5_accuracy: 0.2999 - val_accuracy: 0.1414 - val_loss: 3.0989 - val_top3_accuracy: 0.3301 - val_top5_accuracy: 0.4497 - learning_rate: 3.0000e-04
# Epoch 2/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1367 - loss: 3.4116 - top3_accuracy: 0.2839 - top5_accuracy: 0.3852
# Epoch 2: val_accuracy improved from 0.14141 to 0.20566, saving model to models/effv2b0_best.keras
#
# Epoch 2: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1505 - loss: 3.3351 - top3_accuracy: 0.3019 - top5_accuracy: 0.4066 - val_accuracy: 0.2057 - val_loss: 2.9231 - val_top3_accuracy: 0.3939 - val_top5_accuracy: 0.5006 - learning_rate: 3.0000e-04
# Epoch 3/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1757 - loss: 3.1702 - top3_accuracy: 0.3428 - top5_accuracy: 0.4557
# Epoch 3: val_accuracy improved from 0.20566 to 0.21293, saving model to models/effv2b0_best.keras
#
# Epoch 3: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.1908 - loss: 3.0847 - top3_accuracy: 0.3629 - top5_accuracy: 0.4749 - val_accuracy: 0.2129 - val_loss: 2.8152 - val_top3_accuracy: 0.4360 - val_top5_accuracy: 0.5535 - learning_rate: 3.0000e-04
# Epoch 4/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1992 - loss: 2.9950 - top3_accuracy: 0.3792 - top5_accuracy: 0.5005
# Epoch 4: val_accuracy improved from 0.21293 to 0.23879, saving model to models/effv2b0_best.keras
#
# Epoch 4: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.2130 - loss: 2.9482 - top3_accuracy: 0.3905 - top5_accuracy: 0.5083 - val_accuracy: 0.2388 - val_loss: 2.7237 - val_top3_accuracy: 0.4525 - val_top5_accuracy: 0.5810 - learning_rate: 3.0000e-04
# Epoch 5/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2291 - loss: 2.8739 - top3_accuracy: 0.4207 - top5_accuracy: 0.5370
# Epoch 5: val_accuracy improved from 0.23879 to 0.26020, saving model to models/effv2b0_best.keras
#
# Epoch 5: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.2403 - loss: 2.8218 - top3_accuracy: 0.4290 - top5_accuracy: 0.5422 - val_accuracy: 0.2602 - val_loss: 2.6517 - val_top3_accuracy: 0.4788 - val_top5_accuracy: 0.5988 - learning_rate: 3.0000e-04
# Epoch 6/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2530 - loss: 2.7761 - top3_accuracy: 0.4474 - top5_accuracy: 0.5639
# Epoch 6: val_accuracy improved from 0.26020 to 0.27960, saving model to models/effv2b0_best.keras
#
# Epoch 6: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.2595 - loss: 2.7362 - top3_accuracy: 0.4532 - top5_accuracy: 0.5686 - val_accuracy: 0.2796 - val_loss: 2.5919 - val_top3_accuracy: 0.4962 - val_top5_accuracy: 0.6154 - learning_rate: 3.0000e-04
# Epoch 7/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2548 - loss: 2.7322 - top3_accuracy: 0.4571 - top5_accuracy: 0.5723
# Epoch 7: val_accuracy improved from 0.27960 to 0.28566, saving model to models/effv2b0_best.keras
#
# Epoch 7: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.2693 - loss: 2.6702 - top3_accuracy: 0.4712 - top5_accuracy: 0.5893 - val_accuracy: 0.2857 - val_loss: 2.5516 - val_top3_accuracy: 0.5006 - val_top5_accuracy: 0.6267 - learning_rate: 3.0000e-04
# Epoch 8/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2724 - loss: 2.6461 - top3_accuracy: 0.4837 - top5_accuracy: 0.5976
# Epoch 8: val_accuracy improved from 0.28566 to 0.29899, saving model to models/effv2b0_best.keras
#
# Epoch 8: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - accuracy: 0.2877 - loss: 2.6009 - top3_accuracy: 0.4912 - top5_accuracy: 0.6060 - val_accuracy: 0.2990 - val_loss: 2.5134 - val_top3_accuracy: 0.5018 - val_top5_accuracy: 0.6331 - learning_rate: 3.0000e-04
# Epoch 9/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2772 - loss: 2.6103 - top3_accuracy: 0.4903 - top5_accuracy: 0.6044
# Epoch 9: val_accuracy improved from 0.29899 to 0.30424, saving model to models/effv2b0_best.keras
#
# Epoch 9: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.2921 - loss: 2.5577 - top3_accuracy: 0.5033 - top5_accuracy: 0.6151 - val_accuracy: 0.3042 - val_loss: 2.5113 - val_top3_accuracy: 0.5079 - val_top5_accuracy: 0.6323 - learning_rate: 3.0000e-04
# Epoch 10/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2829 - loss: 2.5825 - top3_accuracy: 0.4974 - top5_accuracy: 0.6198
# Epoch 10: val_accuracy improved from 0.30424 to 0.31192, saving model to models/effv2b0_best.keras
#
# Epoch 10: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.3023 - loss: 2.5124 - top3_accuracy: 0.5156 - top5_accuracy: 0.6332 - val_accuracy: 0.3119 - val_loss: 2.4886 - val_top3_accuracy: 0.5143 - val_top5_accuracy: 0.6331 - learning_rate: 3.0000e-04
# Epoch 11/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2967 - loss: 2.5163 - top3_accuracy: 0.5160 - top5_accuracy: 0.6384
# Epoch 11: val_accuracy improved from 0.31192 to 0.32889, saving model to models/effv2b0_best.keras
#
# Epoch 11: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.3135 - loss: 2.4586 - top3_accuracy: 0.5311 - top5_accuracy: 0.6533 - val_accuracy: 0.3289 - val_loss: 2.4480 - val_top3_accuracy: 0.5273 - val_top5_accuracy: 0.6392 - learning_rate: 3.0000e-04
# Epoch 12/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3026 - loss: 2.5000 - top3_accuracy: 0.5199 - top5_accuracy: 0.6389
# Epoch 12: val_accuracy improved from 0.32889 to 0.33010, saving model to models/effv2b0_best.keras
#
# Epoch 12: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.3177 - loss: 2.4485 - top3_accuracy: 0.5322 - top5_accuracy: 0.6504 - val_accuracy: 0.3301 - val_loss: 2.4407 - val_top3_accuracy: 0.5277 - val_top5_accuracy: 0.6420 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# fine-tuning - разморозил часть исходных слоев, для дообучения

# %%
def set_fine_tuning(base_model: tf.keras.Model, fine_tune_layers: int) -> None:
    """Размораживает последние fine_tune_layers слоёв, кроме BatchNormalization."""
    base_model.trainable = True

    for layer in base_model.layers[:-fine_tune_layers]:
        layer.trainable = False

    for layer in base_model.layers:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

FINE_TUNE_LAYERS = 80
set_fine_tuning(base, fine_tune_layers=FINE_TUNE_LAYERS)

trainable_count = sum(int(layer.trainable) for layer in base.layers)
print(f"Trainable слоёв backbone: {trainable_count} из {len(base.layers)}")

compile_model(model_tl, lr=1e-4)

print("Этап 2: fine-tuning верхних слоёв EfficientNetV2B0.")
hist_ft = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_FINETUNE,
    callbacks=tl_callbacks,
)
# Out:
# Trainable слоёв backbone: 64 из 270
# Этап 2: fine-tuning верхних слоёв EfficientNetV2B0.
# Epoch 1/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3331 - loss: 2.3814 - top3_accuracy: 0.5545 - top5_accuracy: 0.6725
# Epoch 1: val_accuracy improved from 0.33010 to 0.39717, saving model to models/effv2b0_best.keras
#
# Epoch 1: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 55s 107ms/step - accuracy: 0.3613 - loss: 2.2802 - top3_accuracy: 0.5781 - top5_accuracy: 0.6923 - val_accuracy: 0.3972 - val_loss: 2.2145 - val_top3_accuracy: 0.6008 - val_top5_accuracy: 0.7010 - learning_rate: 1.0000e-04
# Epoch 2/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3941 - loss: 2.1598 - top3_accuracy: 0.6133 - top5_accuracy: 0.7170
# Epoch 2: val_accuracy improved from 0.39717 to 0.42303, saving model to models/effv2b0_best.keras
#
# Epoch 2: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4079 - loss: 2.1000 - top3_accuracy: 0.6293 - top5_accuracy: 0.7357 - val_accuracy: 0.4230 - val_loss: 2.1357 - val_top3_accuracy: 0.6263 - val_top5_accuracy: 0.7135 - learning_rate: 1.0000e-04
# Epoch 3/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4324 - loss: 2.0413 - top3_accuracy: 0.6459 - top5_accuracy: 0.7474
# Epoch 3: val_accuracy improved from 0.42303 to 0.43394, saving model to models/effv2b0_best.keras
#
# Epoch 3: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4454 - loss: 1.9802 - top3_accuracy: 0.6628 - top5_accuracy: 0.7618 - val_accuracy: 0.4339 - val_loss: 2.0634 - val_top3_accuracy: 0.6384 - val_top5_accuracy: 0.7244 - learning_rate: 1.0000e-04
# Epoch 4/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4589 - loss: 1.9190 - top3_accuracy: 0.6780 - top5_accuracy: 0.7792
# Epoch 4: val_accuracy improved from 0.43394 to 0.45293, saving model to models/effv2b0_best.keras
#
# Epoch 4: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.4772 - loss: 1.8494 - top3_accuracy: 0.6940 - top5_accuracy: 0.7940 - val_accuracy: 0.4529 - val_loss: 2.0028 - val_top3_accuracy: 0.6461 - val_top5_accuracy: 0.7406 - learning_rate: 1.0000e-04
# Epoch 5/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4904 - loss: 1.7982 - top3_accuracy: 0.7056 - top5_accuracy: 0.8051
# Epoch 5: val_accuracy improved from 0.45293 to 0.47071, saving model to models/effv2b0_best.keras
#
# Epoch 5: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 23s 62ms/step - accuracy: 0.5069 - loss: 1.7424 - top3_accuracy: 0.7217 - top5_accuracy: 0.8158 - val_accuracy: 0.4707 - val_loss: 1.9559 - val_top3_accuracy: 0.6590 - val_top5_accuracy: 0.7451 - learning_rate: 1.0000e-04
# Epoch 6/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5081 - loss: 1.7192 - top3_accuracy: 0.7261 - top5_accuracy: 0.8195
# Epoch 6: val_accuracy improved from 0.47071 to 0.48283, saving model to models/effv2b0_best.keras
#
# Epoch 6: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.5272 - loss: 1.6637 - top3_accuracy: 0.7368 - top5_accuracy: 0.8303 - val_accuracy: 0.4828 - val_loss: 1.9060 - val_top3_accuracy: 0.6731 - val_top5_accuracy: 0.7580 - learning_rate: 1.0000e-04
# Epoch 7/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5401 - loss: 1.6080 - top3_accuracy: 0.7592 - top5_accuracy: 0.8366
# Epoch 7: val_accuracy improved from 0.48283 to 0.49414, saving model to models/effv2b0_best.keras
#
# Epoch 7: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.5568 - loss: 1.5658 - top3_accuracy: 0.7651 - top5_accuracy: 0.8461 - val_accuracy: 0.4941 - val_loss: 1.8695 - val_top3_accuracy: 0.6804 - val_top5_accuracy: 0.7620 - learning_rate: 1.0000e-04
# Epoch 8/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5756 - loss: 1.5188 - top3_accuracy: 0.7742 - top5_accuracy: 0.8492
# Epoch 8: val_accuracy improved from 0.49414 to 0.50141, saving model to models/effv2b0_best.keras
#
# Epoch 8: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.5838 - loss: 1.4854 - top3_accuracy: 0.7824 - top5_accuracy: 0.8579 - val_accuracy: 0.5014 - val_loss: 1.8524 - val_top3_accuracy: 0.6873 - val_top5_accuracy: 0.7665 - learning_rate: 1.0000e-04
# Epoch 9/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5938 - loss: 1.4170 - top3_accuracy: 0.7987 - top5_accuracy: 0.8746
# Epoch 9: val_accuracy improved from 0.50141 to 0.52727, saving model to models/effv2b0_best.keras
#
# Epoch 9: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6048 - loss: 1.3777 - top3_accuracy: 0.8069 - top5_accuracy: 0.8824 - val_accuracy: 0.5273 - val_loss: 1.7850 - val_top3_accuracy: 0.7018 - val_top5_accuracy: 0.7818 - learning_rate: 1.0000e-04
# Epoch 10/12
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6139 - loss: 1.3542 - top3_accuracy: 0.8123 - top5_accuracy: 0.8834
# Epoch 10: val_accuracy did not improve from 0.52727
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.6299 - loss: 1.3108 - top3_accuracy: 0.8211 - top5_accuracy: 0.8906 - val_accuracy: 0.5265 - val_loss: 1.7745 - val_top3_accuracy: 0.7083 - val_top5_accuracy: 0.7859 - learning_rate: 1.0000e-04
# Epoch 11/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6334 - loss: 1.2801 - top3_accuracy: 0.8249 - top5_accuracy: 0.8952
# Epoch 11: val_accuracy improved from 0.52727 to 0.53859, saving model to models/effv2b0_best.keras
#
# Epoch 11: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.6479 - loss: 1.2384 - top3_accuracy: 0.8332 - top5_accuracy: 0.9013 - val_accuracy: 0.5386 - val_loss: 1.7494 - val_top3_accuracy: 0.7156 - val_top5_accuracy: 0.7952 - learning_rate: 1.0000e-04
# Epoch 12/12
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6623 - loss: 1.1903 - top3_accuracy: 0.8448 - top5_accuracy: 0.9051
# Epoch 12: val_accuracy improved from 0.53859 to 0.55030, saving model to models/effv2b0_best.keras
#
# Epoch 12: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.6745 - loss: 1.1452 - top3_accuracy: 0.8564 - top5_accuracy: 0.9156 - val_accuracy: 0.5503 - val_loss: 1.7066 - val_top3_accuracy: 0.7273 - val_top5_accuracy: 0.7980 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 12.

# %%
hist_ft_cont = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_FINETUNE*3,
    initial_epoch=EPOCHS_WARMUP+EPOCHS_FINETUNE,
    callbacks=tl_callbacks,
)
# Out:
# Epoch 25/36
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6865 - loss: 1.1034 - top3_accuracy: 0.8636 - top5_accuracy: 0.9201
# Epoch 25: val_accuracy improved from 0.55030 to 0.56000, saving model to models/effv2b0_best.keras
#
# Epoch 25: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.6905 - loss: 1.0764 - top3_accuracy: 0.8684 - top5_accuracy: 0.9252 - val_accuracy: 0.5600 - val_loss: 1.6676 - val_top3_accuracy: 0.7329 - val_top5_accuracy: 0.8057 - learning_rate: 1.0000e-04
# Epoch 26/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6974 - loss: 1.0650 - top3_accuracy: 0.8639 - top5_accuracy: 0.9184
# Epoch 26: val_accuracy improved from 0.56000 to 0.57051, saving model to models/effv2b0_best.keras
#
# Epoch 26: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.7081 - loss: 1.0240 - top3_accuracy: 0.8771 - top5_accuracy: 0.9300 - val_accuracy: 0.5705 - val_loss: 1.6932 - val_top3_accuracy: 0.7313 - val_top5_accuracy: 0.8053 - learning_rate: 1.0000e-04
# Epoch 27/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7042 - loss: 1.0041 - top3_accuracy: 0.8798 - top5_accuracy: 0.9315
# Epoch 27: val_accuracy did not improve from 0.57051
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.7204 - loss: 0.9676 - top3_accuracy: 0.8863 - top5_accuracy: 0.9366 - val_accuracy: 0.5693 - val_loss: 1.6668 - val_top3_accuracy: 0.7354 - val_top5_accuracy: 0.8081 - learning_rate: 1.0000e-04
# Epoch 28/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7401 - loss: 0.9108 - top3_accuracy: 0.8984 - top5_accuracy: 0.9444
# Epoch 28: val_accuracy improved from 0.57051 to 0.57737, saving model to models/effv2b0_best.keras
#
# Epoch 28: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.7436 - loss: 0.8981 - top3_accuracy: 0.8993 - top5_accuracy: 0.9446 - val_accuracy: 0.5774 - val_loss: 1.6655 - val_top3_accuracy: 0.7459 - val_top5_accuracy: 0.8162 - learning_rate: 1.0000e-04
# Epoch 29/36
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7361 - loss: 0.8952 - top3_accuracy: 0.9007 - top5_accuracy: 0.9449
# Epoch 29: val_accuracy did not improve from 0.57737
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.7411 - loss: 0.8778 - top3_accuracy: 0.9027 - top5_accuracy: 0.9485 - val_accuracy: 0.5774 - val_loss: 1.6636 - val_top3_accuracy: 0.7438 - val_top5_accuracy: 0.8125 - learning_rate: 1.0000e-04
# Epoch 30/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7671 - loss: 0.8235 - top3_accuracy: 0.9146 - top5_accuracy: 0.9532
# Epoch 30: val_accuracy improved from 0.57737 to 0.58141, saving model to models/effv2b0_best.keras
#
# Epoch 30: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.7711 - loss: 0.8026 - top3_accuracy: 0.9176 - top5_accuracy: 0.9562 - val_accuracy: 0.5814 - val_loss: 1.6479 - val_top3_accuracy: 0.7527 - val_top5_accuracy: 0.8194 - learning_rate: 1.0000e-04
# Epoch 31/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7665 - loss: 0.8061 - top3_accuracy: 0.9140 - top5_accuracy: 0.9544
# Epoch 31: val_accuracy improved from 0.58141 to 0.58707, saving model to models/effv2b0_best.keras
#
# Epoch 31: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.7758 - loss: 0.7770 - top3_accuracy: 0.9205 - top5_accuracy: 0.9587 - val_accuracy: 0.5871 - val_loss: 1.6410 - val_top3_accuracy: 0.7588 - val_top5_accuracy: 0.8222 - learning_rate: 1.0000e-04
# Epoch 32/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7822 - loss: 0.7463 - top3_accuracy: 0.9297 - top5_accuracy: 0.9615
# Epoch 32: val_accuracy improved from 0.58707 to 0.59030, saving model to models/effv2b0_best.keras
#
# Epoch 32: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.7912 - loss: 0.7151 - top3_accuracy: 0.9313 - top5_accuracy: 0.9646 - val_accuracy: 0.5903 - val_loss: 1.6390 - val_top3_accuracy: 0.7515 - val_top5_accuracy: 0.8234 - learning_rate: 1.0000e-04
# Epoch 33/36
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7902 - loss: 0.7049 - top3_accuracy: 0.9343 - top5_accuracy: 0.9665
# Epoch 33: val_accuracy improved from 0.59030 to 0.59636, saving model to models/effv2b0_best.keras
#
# Epoch 33: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.7986 - loss: 0.6755 - top3_accuracy: 0.9370 - top5_accuracy: 0.9695 - val_accuracy: 0.5964 - val_loss: 1.6250 - val_top3_accuracy: 0.7620 - val_top5_accuracy: 0.8255 - learning_rate: 1.0000e-04
# Epoch 34/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8019 - loss: 0.6579 - top3_accuracy: 0.9373 - top5_accuracy: 0.9729
# Epoch 34: val_accuracy improved from 0.59636 to 0.59838, saving model to models/effv2b0_best.keras
#
# Epoch 34: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.8120 - loss: 0.6359 - top3_accuracy: 0.9397 - top5_accuracy: 0.9722 - val_accuracy: 0.5984 - val_loss: 1.6295 - val_top3_accuracy: 0.7661 - val_top5_accuracy: 0.8279 - learning_rate: 1.0000e-04
# Epoch 35/36
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8185 - loss: 0.6214 - top3_accuracy: 0.9417 - top5_accuracy: 0.9708
# Epoch 35: val_accuracy improved from 0.59838 to 0.60485, saving model to models/effv2b0_best.keras
#
# Epoch 35: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.8233 - loss: 0.6044 - top3_accuracy: 0.9437 - top5_accuracy: 0.9732 - val_accuracy: 0.6048 - val_loss: 1.6249 - val_top3_accuracy: 0.7608 - val_top5_accuracy: 0.8242 - learning_rate: 1.0000e-04
# Epoch 36/36
# 359/360 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8267 - loss: 0.5816 - top3_accuracy: 0.9469 - top5_accuracy: 0.9754
# Epoch 36: val_accuracy improved from 0.60485 to 0.60525, saving model to models/effv2b0_best.keras
#
# Epoch 36: finished saving model to models/effv2b0_best.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.8290 - loss: 0.5762 - top3_accuracy: 0.9491 - top5_accuracy: 0.9764 - val_accuracy: 0.6053 - val_loss: 1.6798 - val_top3_accuracy: 0.7568 - val_top5_accuracy: 0.8230 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 36.

# %% [markdown]
# ## 7. Графики обучения
#
# Графики позволяют быстро увидеть:
#
# - есть ли переобучение;
# - достигла ли модель плато;
# - помог ли fine-tuning после warmup;
# - не слишком ли большой learning rate.

# %%
def merge_histories(*histories):
    merged = {}
    for history in histories:
        if history is None:
            continue
        for key, values in history.history.items():
            merged.setdefault(key, []).extend(values)
    return merged

def plot_training_curves(history_dict, title="Обучение модели"):
    metrics = [
        ("accuracy", "val_accuracy", "Accuracy"),
        ("top3_accuracy", "val_top3_accuracy", "Top-3 accuracy"),
        ("top5_accuracy", "val_top5_accuracy", "Top-5 accuracy"),
        ("loss", "val_loss", "Loss"),
    ]

    for train_key, val_key, metric_name in metrics:
        if train_key not in history_dict or val_key not in history_dict:
            continue

        plt.figure(figsize=(8, 5))
        plt.plot(history_dict[train_key], label="train")
        plt.plot(history_dict[val_key], label="val")
        plt.title(f"{title}: {metric_name}")
        plt.xlabel("Эпоха")
        plt.ylabel(metric_name)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()

history_all = merge_histories(hist_warmup, hist_ft, hist_ft_cont)
plot_training_curves(history_all, title="EfficientNetV2B0")

# %% [markdown]
# ## 8. Оценка на test и подробные метрики
#
# Обычная accuracy не всегда достаточно информативна. Для 33 классов полезны:
#
# - `top-3 accuracy`: правильная марка попала в 3 наиболее вероятных варианта;
# - `top-5 accuracy`: правильная марка попала в 5 вариантов;
# - precision/recall/F1 по каждому классу;
# - confusion matrix.

# %%
best_tl_path = "models/effv2b0_best.keras"

if os.path.exists(best_tl_path):
    model_tl.load_weights(best_tl_path)
    print("Загружены лучшие веса:", best_tl_path)
else:
    print("Лучший checkpoint не найден, используются текущие веса модели.")

test_metrics = model_tl.evaluate(test_ds, verbose=0)
print("Метрики EfficientNetV2B0 на test:")
for name, value in zip(model_tl.metrics_names, test_metrics):
    print(f"{name}: {value:.4f}")

y_true = df_test["label_idx"].values
y_pred_proba = model_tl.predict(test_ds, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)

print("\nПроверка top-k через sklearn:")
print("Top-3 accuracy:", top_k_accuracy_score(y_true, y_pred_proba, k=3, labels=np.arange(num_classes)))
print("Top-5 accuracy:", top_k_accuracy_score(y_true, y_pred_proba, k=5, labels=np.arange(num_classes)))

report = classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0,
    output_dict=True,
)
report_df = pd.DataFrame(report).T
display(report_df)
# Out:
# Загружены лучшие веса: models/effv2b0_best.keras
# Метрики EfficientNetV2B0 на test:
# loss: 1.6282
# compile_metrics: 0.6028
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step
#
# Проверка top-k через sklearn:
# Top-3 accuracy: 0.7575757575757576
# Top-5 accuracy: 0.8254545454545454
#                precision    recall  f1-score      support
# Acura           0.891892  0.440000  0.589286    75.000000
# Aston Martin    0.761905  0.853333  0.805031    75.000000
# Audi            0.676923  0.586667  0.628571    75.000000
# BMW             0.568627  0.386667  0.460317    75.000000
# Bentley         0.676056  0.640000  0.657534    75.000000
# Buick           0.704918  0.573333  0.632353    75.000000
# Cadillac        0.607143  0.680000  0.641509    75.000000
# Chevrolet       0.744681  0.466667  0.573770    75.000000
# Chrysler        0.640000  0.853333  0.731429    75.000000
# Dodge           0.647887  0.613333  0.630137    75.000000
# FIAT            0.727273  0.746667  0.736842    75.000000
# Ford            0.576923  0.200000  0.297030    75.000000
# GMC             0.726190  0.813333  0.767296    75.000000
# Honda           0.525000  0.280000  0.365217    75.000000
# Hyundai         0.491803  0.400000  0.441176    75.000000
# INFINITI        0.643836  0.626667  0.635135    75.000000
# Jaguar          0.436782  0.506667  0.469136    75.000000
# Jeep            0.666667  0.800000  0.727273    75.000000
# Kia             0.594595  0.293333  0.392857    75.000000
# Land Rover      0.709302  0.813333  0.757764    75.000000
# Lexus           0.525253  0.693333  0.597701    75.000000
# Lincoln         0.559524  0.626667  0.591195    75.000000
# MINI            0.804598  0.933333  0.864198    75.000000
# Mazda           0.418803  0.653333  0.510417    75.000000
# Mercedes-Benz   0.471264  0.546667  0.506173    75.000000
# Mitsubishi      0.515152  0.680000  0.586207    75.000000
# Nissan          0.475410  0.386667  0.426471    75.000000
# Porsche         0.709677  0.586667  0.642336    75.000000
# Ram             0.800000  0.906667  0.850000    75.000000
# Subaru          0.522222  0.626667  0.569697    75.000000
# Toyota          0.433735  0.480000  0.455696    75.000000
# Volkswagen      0.559524  0.626667  0.591195    75.000000
# Volvo           0.409524  0.573333  0.477778    75.000000
# accuracy        0.602828  0.602828  0.602828     0.602828
# macro avg       0.612821  0.602828  0.594204  2475.000000
# weighted avg    0.612821  0.602828  0.594204  2475.000000

# %%
cm = confusion_matrix(y_true, y_pred, labels=np.arange(num_classes))

plt.figure(figsize=(16, 14))
sns.heatmap(
    cm,
    cmap="Blues",
    xticklabels=classes,
    yticklabels=classes,
    square=False,
    cbar=True,
)
plt.title("Confusion matrix на test")
plt.xlabel("Предсказанный класс")
plt.ylabel("Истинный класс")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Нормированная матрица показывает доли ошибок внутри каждого истинного класса.
cm_norm = cm.astype("float") / np.maximum(cm.sum(axis=1, keepdims=True), 1)

plt.figure(figsize=(16, 14))
sns.heatmap(
    cm_norm,
    cmap="Blues",
    xticklabels=classes,
    yticklabels=classes,
    square=False,
    cbar=True,
)
plt.title("Нормированная confusion matrix на test")
plt.xlabel("Предсказанный класс")
plt.ylabel("Истинный класс")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Таблица самых частых пар ошибок.
error_pairs = []
for true_idx in range(num_classes):
    for pred_idx in range(num_classes):
        if true_idx != pred_idx and cm[true_idx, pred_idx] > 0:
            error_pairs.append({
                "true_class": idx2class[true_idx],
                "pred_class": idx2class[pred_idx],
                "count": int(cm[true_idx, pred_idx]),
                "share_within_true_class": float(cm_norm[true_idx, pred_idx]),
            })

error_pairs_df = pd.DataFrame(error_pairs).sort_values(
    ["count", "share_within_true_class"],
    ascending=False,
)
display(error_pairs_df.head(30))
# Out:
#     true_class     pred_class  count  share_within_true_class
# 226    Hyundai          Mazda     12                 0.160000
# 213      Honda         Toyota     10                 0.133333
# 13       Acura          Mazda      7                 0.093333
# 65     Bentley         Jaguar      7                 0.093333
# 81       Buick          Mazda      7                 0.093333
# 40        Audi  Mercedes-Benz      6                 0.080000
# 53         BMW         Jaguar      6                 0.080000
# 57         BMW  Mercedes-Benz      6                 0.080000
# 61         BMW          Volvo      6                 0.080000
# 108  Chevrolet            GMC      6                 0.080000
# 228    Hyundai     Mitsubishi      6                 0.080000
# 290        Kia         Nissan      6                 0.080000
# 11       Acura          Lexus      5                 0.066667
# 70     Bentley     Volkswagen      5                 0.066667
# 86       Buick          Volvo      5                 0.066667
# 143      Dodge     Mitsubishi      5                 0.066667
# 150       FIAT           MINI      5                 0.066667
# 163       Ford          Dodge      5                 0.066667
# 165       Ford            GMC      5                 0.066667
# 167       Ford        Hyundai      5                 0.066667
# 283        Kia        Hyundai      5                 0.066667
# 292        Kia         Toyota      5                 0.066667
# 469     Toyota          Lexus      5                 0.066667
# 472     Toyota         Nissan      5                 0.066667
# 68     Bentley  Mercedes-Benz      4                 0.053333
# 134      Dodge       Chrysler      4                 0.053333
# 151       FIAT          Mazda      4                 0.053333
# 180       Ford            Ram      4                 0.053333
# 181       Ford         Toyota      4                 0.053333
# 200      Honda        Hyundai      4                 0.053333

# %% [markdown]
# ## 9. Анализ ошибочных предсказаний
#
# - похожие модели
# - фото салона, дисков и т.п. сбивают нейронку

# %%
def show_misclassified_examples(df, y_true, y_pred, y_pred_proba, n=24):
    wrong_idx = np.where(y_true != y_pred)[0]
    if len(wrong_idx) == 0:
        print("Ошибок не найдено.")
        return

    # Уверенность модели в ошибочном предсказании.
    wrong_conf = y_pred_proba[wrong_idx, y_pred[wrong_idx]]
    order = wrong_idx[np.argsort(-wrong_conf)]
    selected = order[:n]

    cols = 4
    rows = int(np.ceil(len(selected) / cols))
    plt.figure(figsize=(4 * cols, 4 * rows))

    for i, idx in enumerate(selected, start=1):
        img = decode_image(df.iloc[idx]["path"]).numpy()

        true_name = idx2class[int(y_true[idx])]
        pred_name = idx2class[int(y_pred[idx])]
        conf = float(y_pred_proba[idx, y_pred[idx]])

        top5 = np.argsort(-y_pred_proba[idx])[:5]
        top5_text = ", ".join([f"{idx2class[int(j)]}: {y_pred_proba[idx, j]:.2f}" for j in top5])

        plt.subplot(rows, cols, i)
        plt.imshow(img)
        plt.axis("off")
        plt.title(f"true: {true_name}\npred: {pred_name} ({conf:.2f})", fontsize=9)
        print(f"{idx}. true={true_name}, pred={pred_name}, top5=[{top5_text}], path={df.iloc[idx]['path']}")

    plt.tight_layout()
    plt.show()

show_misclassified_examples(df_test, y_true, y_pred, y_pred_proba, n=24)
# Out:
# 869. true=Ford, pred=Audi, top5=[Audi: 0.99, Hyundai: 0.00, Ford: 0.00, Jeep: 0.00, Mitsubishi: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Mustang_2011_34_18_410_50_8_73_56_188_nan_RWD_4_2_Convertible_UDC.jpg
# 551. true=Chevrolet, pred=Land Rover, top5=[Land Rover: 0.98, Jeep: 0.01, GMC: 0.00, Chevrolet: 0.00, Ford: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Blazer_1998_21_15_190_43_6_67_64_nan_16_RWD_4_2_SUV_fYG.jpg
# 555. true=Chevrolet, pred=GMC, top5=[GMC: 0.98, Chrysler: 0.01, Toyota: 0.00, Jeep: 0.00, Volkswagen: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Silverado 2500HD_2016_53_20_360_60_8_80_78_nan_nan_RWD_5_4_Pickup_Xel.jpg
# 879. true=Ford, pred=Ram, top5=[Ram: 0.98, GMC: 0.01, Audi: 0.00, Mitsubishi: 0.00, Chrysler: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2011_46_18_380_62_8_79_77_nan_nan_RWD_5_4_Pickup_Lwh.jpg
# 963. true=GMC, pred=FIAT, top5=[FIAT: 0.98, MINI: 0.02, Chevrolet: 0.00, Dodge: 0.00, GMC: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/GMC/GMC_Yukon_2014_58_20_400_62_8_79_76_nan_14_RWD_7_4_SUV_HMp.jpg
# 452. true=Cadillac, pred=Lincoln, top5=[Lincoln: 0.97, Cadillac: 0.03, Volvo: 0.00, Mitsubishi: 0.00, Chevrolet: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Cadillac/Cadillac_CT5_2020_36_18_230_20_4_74_57_193_23_RWD_5_4_4dr_zBr.jpg
# 886. true=Ford, pred=Chevrolet, top5=[Chevrolet: 0.97, Ford: 0.01, GMC: 0.01, Subaru: 0.00, Nissan: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Super Duty F-250_2019_55_18_380_62_8_80_78_250_nan_RWD_5_4_Pickup_FAd.jpg
# 66. true=Acura, pred=Honda, top5=[Honda: 0.96, Volkswagen: 0.01, Ford: 0.01, Mazda: 0.00, Hyundai: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Acura/Acura_ILX_2014_28_16_110_15_4_70_55_179_39_FWD_5_4_4dr_rxS.jpg
# 2148. true=Ram, pred=Jeep, top5=[Jeep: 0.96, GMC: 0.01, Mitsubishi: 0.00, Chevrolet: 0.00, Cadillac: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ram/Ram_1500_2019_38_18_300_36_6_82_77_232_20_RWD_6_4_Pickup_GUW.jpg
# 559. true=Chevrolet, pred=GMC, top5=[GMC: 0.96, Cadillac: 0.01, Land Rover: 0.01, Jeep: 0.01, Ram: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Suburban_2017_49_18_350_53_8_80_74_nan_16_RWD_8_4_SUV_mkp.jpg
# 569. true=Chevrolet, pred=Mercedes-Benz, top5=[Mercedes-Benz: 0.96, BMW: 0.02, Chevrolet: 0.01, Acura: 0.01, GMC: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Bolt EV_2017_36_17_200_nan_nan_69_62_164_nan_FWD_5_4_4dr_YhF.jpg
# 992. true=Honda, pred=Aston Martin, top5=[Aston Martin: 0.95, INFINITI: 0.02, Mercedes-Benz: 0.02, Bentley: 0.01, Porsche: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Honda/Honda_Accord_2011_25_17_190_24_4_72_56_191_22_FWD_5_2_2dr_ZTj.jpg
# 1421. true=Kia, pred=Mitsubishi, top5=[Mitsubishi: 0.95, Mazda: 0.01, Toyota: 0.00, Lexus: 0.00, Lincoln: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Kia/Kia_Sportage_2015_25_18_180_24_4_73_64_174_21_FWD_5_4_SUV_qse.jpg
# 2284. true=Toyota, pred=Ram, top5=[Ram: 0.95, Chevrolet: 0.02, GMC: 0.02, Ford: 0.00, Cadillac: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Toyota/Toyota_Tundra_2011_29_18_310_46_8_79_75_nan_15_RWD_6_4_Pickup_BoR.jpg
# 350. true=Bentley, pred=Volkswagen, top5=[Volkswagen: 0.95, Mercedes-Benz: 0.04, Bentley: 0.00, Audi: 0.00, BMW: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Bentley/Bentley_Bentayga_2020_203_21_540_40_8_78_68_202_nan_AWD_5_4_SUV_iTS.jpg
# 1117. true=Hyundai, pred=Mazda, top5=[Mazda: 0.95, Mitsubishi: 0.03, Kia: 0.01, Buick: 0.00, Hyundai: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Hyundai/Hyundai_Elantra_2013_17_16_140_18_4_69_56_178_28_FWD_5_4_4dr_dvs.jpg
# 977. true=Honda, pred=Mitsubishi, top5=[Mitsubishi: 0.95, INFINITI: 0.02, Toyota: 0.01, Ford: 0.01, Honda: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Honda/Honda_CR-V_2019_27_18_190_15_4_73_66_180_28_FWD_5_4_SUV_qUP.jpg
# 875. true=Ford, pred=Land Rover, top5=[Land Rover: 0.95, Ford: 0.02, Lincoln: 0.02, Dodge: 0.00, Chrysler: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Ford/Ford_Flex_2017_40_19_280_35_6_75_68_201_nan_AWD_7_4_SUV_APp.jpg
# 2216. true=Subaru, pred=Volvo, top5=[Volvo: 0.95, Subaru: 0.03, Jaguar: 0.01, BMW: 0.00, Buick: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Subaru/Subaru_Legacy_2014_21_16_170_25_4_71_59_187_24_AWD_5_4_4dr_ckl.jpg
# 2239. true=Subaru, pred=Porsche, top5=[Porsche: 0.95, Mercedes-Benz: 0.04, Cadillac: 0.00, BMW: 0.00, INFINITI: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Subaru/Subaru_BRZ_2017_28_17_200_20_4_69_50_166_24_RWD_4_2_2dr_vEg.jpg
# 579. true=Chevrolet, pred=FIAT, top5=[FIAT: 0.95, Volkswagen: 0.02, Mitsubishi: 0.02, Toyota: 0.00, Subaru: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Spark_2015_13_15_840_12_4_62_61_144_30_FWD_4_4_4dr_kHz.jpg
# 2271. true=Toyota, pred=Mazda, top5=[Mazda: 0.94, Hyundai: 0.02, Mitsubishi: 0.01, Volkswagen: 0.01, Buick: 0.01], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Toyota/Toyota_Avalon_2013_39_18_260_35_6_72_57_195_nan_FWD_5_4_4dr_hHm.jpg
# 1631. true=Lincoln, pred=Volvo, top5=[Volvo: 0.94, Audi: 0.02, Dodge: 0.02, Acura: 0.01, Jaguar: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Lincoln/Lincoln_Navigator_2020_96_22_450_35_6_79_76_210_16_4WD_7_4_SUV_rfM.jpg
# 582. true=Chevrolet, pred=Audi, top5=[Audi: 0.94, Volkswagen: 0.03, Ford: 0.01, Jaguar: 0.01, Bentley: 0.00], path=/home/sm/Desktop/ml/CarBrandClassificationDataset/test/Chevrolet/Chevrolet_Camaro_2011_29_18_310_36_6_75_54_190_17_RWD_4_2_Convertible_AJK.jpg

# %% [markdown]
# Общий вывод по работе: работает распознавание хороших ракурсов, но с учетом того что многие машины отличаются друг от друга по сути только шильдиком, тут тоже есть ошибки.
#
# Отвратительную роль играют выбросы - фото салона, дисков, брошюрок, 'машина на фоне самолета', 'три машины где-то далеко' и т.п. - они не только идут методом случайного угадывания, но еще и портят общее обучение модели.
#
# К сожалению выбросить их просто так не получиться
# - они все-таки часть датасета и составляют значительную его часть
# - есть редкие модели - винтажные хонды, астон мартины и т.д. у них тоже всего несколько фоток в датасете и при автоматической чистке мы тоже выкинем
